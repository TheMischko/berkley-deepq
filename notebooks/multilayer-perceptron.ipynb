# %% [markdown]
# # Vícevrstvé sítě a zpětná propagace
#
# V tomto cvičení si vyzkoušíme klasifikaci pomocí vícevrstvých dopředných sítí, tzv. vícevrstvých perceptronů. Pro porovnání se přitom zaměříme na stejný dataset jako minule, tedy klasifikaci CIFAR-10.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import torch
from torch import nn
import torch.nn.functional as F

# %%
sys.path.insert(0, "E:\\Projects\\py-berkley\\neural")

# %%
from Layer import Layer
from Loader import Loader
from BatchLoader import BatchLoader
from Stats import Stats
from StochasticGradientDescent import StochasticGradientDescent
from LinearLayer import LinearLayer
from SoftmaxCrossEntropyLayer import SoftmaxCrossEntropyLayer
from SigmoidLayer import SigmoidLayer
import neural

# %% [markdown]
# Výchozím datovým typem v pytorchi je 32bitový `float`, který postačuje pro trénování modelů, avšak může způsobovat problémy při kontrole implementace zpětného průchodu (gradient check). Následující buňka proto mění výchozí typ na `double`, byť v praxi, zejména při použití GPU, se z důvodu úspory paměti a času pro trénování nepoužívá. Naopak se lze setkat i s nižší přesností, např. 16bitovým floating point (half-precision) či dokonce 1bitovými binárními čísly.

# %%
torch.set_default_dtype(torch.double)

# %% [markdown]
# ## Načtení dat

# %%
import torchvision

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True)
trainset
# Out:
# Files already downloaded and verified
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train

# %%
trainset.data.shape, trainset.data.dtype
# Out:
# ((50000, 32, 32, 3), dtype('uint8'))

# %%
type(trainset.targets), len(trainset.targets)
# Out:
# (list, 50000)

# %%
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True)
testset
# Out:
# Files already downloaded and verified
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test

# %%
testset.data.shape, testset.data.dtype
# Out:
# ((10000, 32, 32, 3), dtype('uint8'))

# %%
type(testset.targets), len(testset.targets)
# Out:
# (list, 10000)

# %% [markdown]
# ## Matice trénovacích a validačních dat

# %% [markdown]
# Matice **trénovacích** dat:

# %%
# prevedeme na pytorch tensor a dostaneme do rozsahu [0...1] (vydelime 255)
# pozn.: nastavujeme dtype explicitne, jinak PyTorch prevezme dtype z numpy pole `trainset.train_data`
X_train = torch.tensor(trainset.data, dtype=torch.get_default_dtype()) / 255.

# reshape na matici s obrazky na radcich
X_train = X_train.reshape(X_train.shape[0], -1)

X_train.dtype, X_train.shape
# Out:
# (torch.float64, torch.Size([50000, 3072]))

# %% [markdown]
# **Labely** trénovacích dat:

# %%
y_train = torch.tensor(trainset.targets)
y_train.dtype, y_train.shape
# Out:
# (torch.int64, torch.Size([50000]))

# %% [markdown]
# Matice **validačních** dat:

# %%
# prevedeme na pytorch tensor a dostaneme do rozsahu [0...1] (vydelime 255)
# pozn.: nastavujeme dtype explicitne, jinak PyTorch prevezme dtype z numpy pole `testset.test_data`
X_valid = torch.tensor(testset.data, dtype=torch.get_default_dtype()) / 255.

# reshape na matici s obrazky na radcich
X_valid = X_valid.reshape(X_valid.shape[0], -1)

X_valid.dtype, X_valid.shape
# Out:
# (torch.float64, torch.Size([10000, 3072]))

# %% [markdown]
# **Labely** validačních dat:

# %%
y_valid = torch.tensor(testset.targets)
y_valid.dtype, y_valid.shape
# Out:
# (torch.int64, torch.Size([10000]))

# %% [markdown]
# ## Modul: lineární vrstva

# %% [markdown]
# Základním kamenem lineární klasifikace je lineární, či technicky vzato správně afinní operace, jejíž
#
# **dopředný průchod** má formu:
# $$s = Wx + b$$
#
# Z uvedeného vztahu se pak odvozuje podoba gradientu na váhy a vstup při zpětné propagaci.
#
# **Zpětný průchod**
#
# Gradient na váhovou matici $W$
# $$\frac{\partial L}{\partial W} = \frac{\partial L}{\partial s} x^\top$$
#
# Gradient na bias vektor $b$
# $$\frac{\partial L}{\partial b} = \frac{\partial L}{\partial s}$$
#
# Gradient na vstup $x$
# $$\frac{\partial L}{\partial x} = W^\top \frac{\partial L}{\partial s}$$
#
# Jak jsme si ukázali v přednášce, modularizací této operace vyjádřením jako vrstvy s dopředným a zpětným průchodem je možné výpočty libovolně řetězit a kombinovat, což usnadňuje sestavení vícevrstvých hlubokých sítí.
#
# ### Modularizace
#
# Vzor obecné vrstvy je definován v modulu `ans`. Je to třída, kde důležité je následující:
# ``` python
# class Layer(object):
#
#     def __init__(self):
#         super().__init__()
#         self.params = {}
#         self._cache = None
#
#     def forward(self, *args, **kwargs):
#         raise NotImplementedError
#
#     def backward(self, *args, **kwargs):
#         raise NotImplementedError
# ```
#
# Každá vrstva typu `Layer` má parametry definované slovníkem `params`, který mapuje jména parametrů na jejich hodnoty. Dále obsahuje atribut `_cache`, který ukládá hodnoty z dopředného průchodu pro efektivnější výpočet zpětného průchodu.
#
# Modularizaci lineární vrstvy tedy provedeme tak, že ze vzoru `Layer` odvodíme třídu `Linear` a implementujeme její dvě metody, jednu pro dopředný průchod a druhou pro zpětný.
# 1. Dopředný průchod vrátí $s$ dle výše uvedeného vzorce a pro efektivní výpočty uloží některé proměnné do paměti (`_cache`).
# 2. Zpětný průchod přijme nějaký příchozí gradient ${\partial L} / {\partial s}$ (např. z nadřazené vrstvy či lossu), spočítá gradienty na svoje parametry $W$ a $b$ a vstup $x$ a vrátí k případné další propagaci výpočetním grafem.
#
# **Pozn.:** Všechny funkce navrhneme tak, aby pracovaly s dávkami vzorků (mini-batch), nikoliv pro samostatné vektory. Změna se projeví pouze tak, že se gradienty pro každý vzorek sečtou. Pokud např.
# $$ s^{(1)}=Wx^{(1)} + b $$
# $$ s^{(2)}=Wx^{(2)} + b $$
# tj. minibatch o délce dvou, během jejíhož výpočtu se parametry $W$ a $b$ nemění, pak výsledný gradient za celou dávku je
# $$ \frac{\partial L}{\partial W} = \frac{\partial L}{\partial s^{(1)}}{x^{(1)}}^\top + \frac{\partial L}{\partial s^{(2)}}{x^{(2)}}^\top $$

# %%
class Linear(Layer):

    def __init__(self, input_dim, output_dim, weight_scale=1e-3):
        """
        input_dim    ... rozmer vstupu
        output_dim   ... rozmer vystupu
        weight_scale ... muze byt `float` nebo retezec s nazvem inicializacni metody
        """
        super().__init__()

        #################################################################
        # ZDE DOPLNIT

        # pripad weight_scale == 'xavier' znamena automaticky nastavit
        # weight_scale na hodnotu zavislou na velikosti vstupu
        self.weight_scale = weight_scale

        # slovnik `params` drzi hodnoty parametru vrstvy, tj. napr. vahovou matici a bias
        self.params = {
            'weights': torch.randn(input_dim, output_dim)/np.sqrt(input_dim),
            'bias': torch.zeros(output_dim)
        }

        #################################################################

    def forward(self, inputs):
        """
        dopredny pruchod linearni vrstvou

        vstup:
            inputs  ... N x D matice vstupu (minibatch o delce N)

        vystup:
            score   ... N x H vystupni linearni skore
        """

        #################################################################
        # ZDE DOPLNIT
        w = self.params['weights']
        b = self.params['bias']
        score = (inputs @ w) + b
        self._cache = {'score': score, 'inputs': inputs}

        #################################################################
        return score

    def backward(self, dscore):
        """
        zpetny pruchod linearni vrstvou

        vstup:
            dscore  ... N x H prichozi gradient z nadrazene vrstvy

        vystup:
            dinputs ... N x D gradient na vstup, tj. na `inputs` metody `forward`
            grads   ... slovnik mapujici jmena parametru na jejich gradienty
        """

        #################################################################
        # ZDE DOPLNIT

        # nacist cache
        f_score = self._cache['score']
        inputs = self._cache['inputs']
        w = self.params['weights']

        # spocitat gradienty
        dinputs = dscore @ torch.t(w)
        dweights = torch.t(inputs) @ dscore
        dbias = torch.t(torch.sum(dscore, dim=0))

        ##################################################################

        return dinputs, {'weights': dweights, 'bias': dbias}

# %% [markdown]
# Zda si dopředný a zpětný průchod odpovídají zjistíme kontrolou získaného gradientu. Vrstvu vyzkoušíme na malých testovacích "dummy" datech s náhodnými čísly, kterými nasimulujeme vstup a příchozí gradient "shora". Chyba gradientu u všech parametrů i vstupu by měla být malá, pro datový typ `double`, se kterým pracujeme, řádově $10^{-5}$. Metoda `ans.check_gradients` navíc vrací numerický i námi implemetovaný gradient a při problémech s implementací je tak možné je porovnat.

# %%
# zkusebni instance modelu (vstup vel. 5, vystup vel. 3)
linear_layer = LinearLayer(5, 3)

# toy vstupni data (pocet_vektoru x dimenze_vektoru)
inputs = torch.randn(10, 5)

# "simulace" gradientu na vystup
dscore = torch.randn(10, 3)

# porovnani; rel. chyba gradientu by mela byt velmi mala, pro float32 radove 1e-5
grads, grads_num = neural.check_gradients(linear_layer, inputs, dscore)
# Out:
# dinput1 error:  6.345825200634588e-11
# dweights error:  5.5982128077793536e-12
# dbias error:  2.7104262770345582e-12

# %% [markdown]
# ## Modul: softmax cross entropy

# %% [markdown]
# Kritérium je svým způsobem "terminální" vrstva, kde výpočet končí. Hodnota lossu určí, jak moc je výstup ze sítě (vstup do lossu) špatný porovnáním se správnou hodnotou (target / label / ground truth / reference). Druhým krokem je vrátit gradient na svůj vstup (tedy výstup sítě), který říká, co a jak změnit. Jak si tento gradient síť dále přebere a propaguje, už je "její starost".
#
# Výstup logistické regrese je definován jako softmax vstupních skóre
# $$ p_c = \frac{\exp{s_c}}{\sum_{i=0}^{C-1}\exp{s_i}} $$
#
# kde $s_c = w_c^\top x$ je lineární skóre, $w_c$ je $c$-tý řádek matice vah $W$. Pravděpodobnosti $p_c$ pak vstupují do křížové entropie, která je porovná se správným rozložením (samé nuly kromě jedné jedničky pro správnou třídu). Výsledkem dopředného průchodu je jediné číslo $L$ udávající hodnotu lossu.
#
# **Dopředný průchod**
# $$ L = -\sum_{c=0}^{C-1}\left(\boldsymbol{1}(c=y)\log p_c\right) = -\log p_y $$
#
# Jelikož je softmax monotónní operace, neboli pořadí prvků dle jejich velikosti se po provedení nemění, není $p_c$ v testovací fázi (inference) potřeba počítat. Můžeme proto predikovat už na základě skóre a normalizaci na pravděpodobnosti si odpustit.
#
# Softmax tedy budeme používat pouze ve spojitosti s lossem. Loss funkci proto zadefinujeme tak, že bude místo pravděpodobností přijímat skóre a softmax bude její součástí. Výhodou tohoto přístupu navíc je, že budeme moci snadno vyměnit loss např. za SVM hinge, které rovněž přijímá skóre, nikoliv pravděpodobnosti.
#
# **Zpětný průchod**
#
# Gradient na vektor skóre $s$ je
# $$ \frac{\partial L}{\partial s_c} = p_c - \boldsymbol{1}(c=y) $$
#
# **Poznámky**
# - Nezapomínejme, že uvedené vzorce platí pro *jeden* vstupní vektor potažmo skóre $s$. V implementaci však budeme pracovat s minidávkami o délce $N$, tj. skóre bude tvaru $N \times C$, kde $C$ je počet tříd. Výpočet lossu $L$ je proto nutné provést pro každý vektor skóre $s^{(n)}$ ($n = 1, \ldots, N$) v dávce a dílčí výsledky *sečíst*. Gradient pak musí být na každý vektor $s^{(n)}$ v dávce, tedy stejně jako vstup o rozměru $N \times C$.
# - Pro lepší numerickou stabilitu před softmaxem odečtěte od všech skóre jejich max. hodnotu, pro každý vektor skóre v minidávce zvlášť. Vzhledem k tomu, že odečtení bude v čitateli i ve jmenovateli softmaxu, matematicky se jedná jen o rozšíření zlomku. Ale bude se pracovat s menšími čísly, a tak se sníží riziko přetečení a různých nekonečen.

# %%
class SoftmaxCrossEntropy(Layer):
    
    def __init__(self, average=True):
        """
        average ... pokud je `True`, hodnota lossu nebude soucet, ale prumer pres davku (minibatch)
        """
        super().__init__()
        self.average = average
    
    def forward(self, scores, targets=None):
        """
        vstup:
            scores  ... N x C matice skore, n-ty radek je skore pro n-ty obrazek
            targets ... int vektor o rozmeru N, kde n-ty prvek znaci index spravne tridy n-teho obrazku
            
            Pokud je `targets` `None`, pak `scores` musi byt `tuple` (par) obsahujici oba vstupy. Je tomu
            tak kvuli rozhrani automaticke kontroly gradientu.
        """
        
        if targets is None:
            scores, targets = scores

        # Score normalization
        scores = scores - torch.max(scores, dim=1).values.reshape(-1, 1)
        probs = torch.exp(scores)/torch.sum(torch.exp(scores), dim=1).reshape(-1, 1)
        loss = torch.sum( -torch.log( probs[range(targets.shape[0]), targets]))
        
        if self.average:
            loss = loss / targets.shape[0]
        
        self._cache = {
            'probs': probs,
            'targets': targets,
            'scores': scores
        }

        return loss
    
    def backward(self, dloss=1.):
        """
        zpetny pruchod linearni vrstvou

        vstup:
            dloss  ... gradient z nadrazene vrstvy, skalar

        vystup:
            dscores ... N x D gradient na vstup
            grads   ... slovnik mapujici jmena parametru na jejich gradienty (prazdny, `Softmax` nema parametry)
        """
        
        #################################################################
        # ZDE DOPLNIT
        
        # nacist cache

        dscores = self._cache['probs']
        targets = self._cache['targets']
        y_matrix = torch.zeros(targets.shape[0], dscores.shape[1])
        y_matrix[range(targets.shape[0]), targets] = 1
        dscores = dscores - y_matrix * dloss

        if self.average:
            dscores = dscores/targets.shape[0]
        
        dparams = {}
        
        #################################################################

        return dscores, dparams

# %%
# zkusebni instance modelu
smax_ce = SoftmaxCrossEntropyLayer(average=True)

# toy vstupni data (pocet_vektoru x dimenze_vektoru)
scores = torch.randn(10, 3)
targets = torch.randint(3, (10,))

# porovnani; rel. chyba gradientu by mela byt velmi mala, pro float32 radove 1e-5
grads, grads_num = neural.check_gradients(smax_ce, (scores, targets), torch.ones(1), input_names=('scores', 'targets'))
# Out:
# dscores error:  9.412383952991649e-10

# %% [markdown]
# ## Trénování a validace

# %% [markdown]
# Jak jsme si ukázali v prvním cvičení, nejrozšířenějším způsobem učení neuronových sítí je iterativní minimimalizace metodou stochastic gradient descent (SGD). Po malých dávkách síť vždy predikuje výstup, ten se nějakým kritériem (loss) porovná se správnou hodnotou (ground truth) a na základě tohoto rozdílu se upraví vnitřní parametry modelu tak, aby příště výstup co možná nejlépe odpovídal anotaci. Neustále se tedy opakuje:
# 1. navzorkování dávky dat (minibatch)
# 2. dopedný průchod (výstupní skóre)
# 3. vyhocení kritéria (loss)
# 3. zpětný průchod (gradient na parametry)
# 4. update parametrů
#
# Jelikož trénování téměř libovolného dopředného modelu pro klasifikaci lze provést tímto způsobem, celý proces je zalaben do metody `train` v modulu `ans`. Podobně je v modulu `ans` implementována i metoda `validate` sloužící pro validaci. Obě metody byly navrženy tak, aby připomínaly způsob trénování v PyTorchi.
#
# Metody přijímají několik společných parametrů:
# - `model` ... objekt typu `ans.Layer` implementující metody `forward` a `backward`
# - `crit` ... kritérium (např. softmax cross entropy); vrací skalár a rovněž musí implementovat metody `forward` a `backward`
# - `loader` ... iterátor typu `ans.BatchLoader`, který prochází data po minidávkách a vždy vrací dvojci `(X_data, y_data)`
# - `stats` ... objekt, který shromažďuje statistiky a následně vykreslí do tabulky či grafu
#
# U `train` je jeden parametr navíc:
# - `optimizer` ... objekt, který je zodpovědný za update parametrů modelu v každé iteraci; jejich seznam přebírá v konstruktoru

# %%
#################################################################
# ZDE DOPLNIT

softmax_model = LinearLayer(X_train.shape[1], torch.unique(y_train).shape[0])
sce = SoftmaxCrossEntropy()

train_loader = BatchLoader(X_train, y_train, 64, 'train', shuffle=True)
valid_loader = BatchLoader(X_valid, y_valid, 64, 'valid', shuffle=True)

optimizer = StochasticGradientDescent(softmax_model.params, learning_rate=0.001, weight_decay_l2=0.001)

#################################################################

softmax_stats = Stats()

# %%
# %pdb off

#################################################################
# ZDE DOPLNIT

for epoch in range(1):
    softmax_stats.new_epoch()
    neural.train(softmax_model, sce, train_loader, optimizer, softmax_stats)
    neural.validate(softmax_model, sce, valid_loader, softmax_stats)
    
#################################################################
# Out:
# Automatic pdb calling has been turned OFF
# train data stats for 0 step
# Loss = 2.434
# Accuracy = 0.109
# ------------------------------
# train data stats for 1 step
# Loss = 2.326
# Accuracy = 0.188
# ------------------------------
# train data stats for 2 step
# Loss = 2.340
# Accuracy = 0.094
# ------------------------------
# train data stats for 3 step
# Loss = 2.481
# Accuracy = 0.094
# ------------------------------
# train data stats for 4 step
# Loss = 2.447
# Accuracy = 0.094
# ------------------------------
# train data stats for 5 step
# Loss = 2.408
# Accuracy = 0.125
# ------------------------------
# train data stats for 6 step
# Loss = 2.288
# Accuracy = 0.141
# ------------------------------
# train data stats for 7 step
# Loss = 2.464
# Accuracy = 0.031
# ------------------------------
# train data stats for 8 step
# Loss = 2.354
# Accuracy = 0.141
# ------------------------------
# train data stats for 9 step
# Loss = 2.315
# Accuracy = 0.047
# ------------------------------
# train data stats for 10 step
# Loss = 2.416
# Accuracy = 0.078
# ------------------------------
# train data stats for 11 step
# Loss = 2.301
# Accuracy = 0.125
# ------------------------------
# train data stats for 12 step
# Loss = 2.373
# Accuracy = 0.109
# ------------------------------
# train data stats for 13 step
# Loss = 2.302
# Accuracy = 0.141
# ------------------------------
# train data stats for 14 step
# Loss = 2.343
# Accuracy = 0.125
# ------------------------------
# train data stats for 15 step
# Loss = 2.381
# Accuracy = 0.141
# ------------------------------
# train data stats for 16 step
# Loss = 2.311
# Accuracy = 0.047
# ------------------------------
# train data stats for 17 step
# Loss = 2.344
# Accuracy = 0.109
# ------------------------------
# train data stats for 18 step
# Loss = 2.314
# Accuracy = 0.109
# ------------------------------
# train data stats for 19 step
# Loss = 2.362
# Accuracy = 0.141
# ------------------------------
# train data stats for 20 step
# Loss = 2.417
# Accuracy = 0.125
# ------------------------------
# train data stats for 21 step
# Loss = 2.269
# Accuracy = 0.203
# ------------------------------
# train data stats for 22 step
# Loss = 2.315
# Accuracy = 0.125
# ------------------------------
# train data stats for 23 step
# Loss = 2.390
# Accuracy = 0.125
# ------------------------------
# train data stats for 24 step
# Loss = 2.308
# Accuracy = 0.109
# ------------------------------
# train data stats for 25 step
# Loss = 2.356
# Accuracy = 0.047
# ------------------------------
# train data stats for 26 step
# Loss = 2.282
# Accuracy = 0.172
# ------------------------------
# train data stats for 27 step
# Loss = 2.291
# Accuracy = 0.141
# ------------------------------
# train data stats for 28 step
# Loss = 2.308
# Accuracy = 0.125
# ------------------------------
# train data stats for 29 step
# Loss = 2.252
# Accuracy = 0.141
# ------------------------------
# train data stats for 30 step
# Loss = 2.342
# Accuracy = 0.109
# ------------------------------
# train data stats for 31 step
# Loss = 2.298
# Accuracy = 0.172
# ------------------------------
# train data stats for 32 step
# Loss = 2.358
# Accuracy = 0.062
# ------------------------------
# train data stats for 33 step
# Loss = 2.310
# Accuracy = 0.078
# ------------------------------
# train data stats for 34 step
# Loss = 2.316
# Accuracy = 0.094
# ------------------------------
# train data stats for 35 step
# Loss = 2.273
# Accuracy = 0.125
# ------------------------------
# train data stats for 36 step
# Loss = 2.278
# Accuracy = 0.109
# ------------------------------
# train data stats for 37 step
# Loss = 2.309
# Accuracy = 0.078
# ------------------------------
# train data stats for 38 step
# Loss = 2.321
# Accuracy = 0.078
# ------------------------------
# train data stats for 39 step
# Loss = 2.289
# Accuracy = 0.141
# ------------------------------
# train data stats for 40 step
# Loss = 2.262
# Accuracy = 0.141
# ------------------------------
# train data stats for 41 step
# Loss = 2.303
# Accuracy = 0.172
# ------------------------------
# train data stats for 42 step
# Loss = 2.268
# Accuracy = 0.188
# ------------------------------
# train data stats for 43 step
# Loss = 2.292
# Accuracy = 0.141
# ------------------------------
# train data stats for 44 step
# Loss = 2.286
# Accuracy = 0.109
# ------------------------------
# train data stats for 45 step
# Loss = 2.228
# Accuracy = 0.250
# ------------------------------
# train data stats for 46 step
# Loss = 2.259
# Accuracy = 0.109
# ------------------------------
# train data stats for 47 step
# Loss = 2.296
# Accuracy = 0.141
# ------------------------------
# train data stats for 48 step
# Loss = 2.286
# Accuracy = 0.125
# ------------------------------
# train data stats for 49 step
# Loss = 2.307
# Accuracy = 0.188
# ------------------------------
# train data stats for 50 step
# Loss = 2.282
# Accuracy = 0.094
# ------------------------------
# train data stats for 51 step
# Loss = 2.260
# Accuracy = 0.156
# ------------------------------
# train data stats for 52 step
# Loss = 2.288
# Accuracy = 0.094
# ------------------------------
# train data stats for 53 step
# Loss = 2.265
# Accuracy = 0.125
# ------------------------------
# train data stats for 54 step
# Loss = 2.257
# Accuracy = 0.141
# ------------------------------
# train data stats for 55 step
# Loss = 2.238
# Accuracy = 0.172
# ------------------------------
# train data stats for 56 step
# Loss = 2.279
# Accuracy = 0.125
# ------------------------------
# train data stats for 57 step
# Loss = 2.280
# Accuracy = 0.156
# ------------------------------
# train data stats for 58 step
# Loss = 2.278
# Accuracy = 0.172
# ------------------------------
# train data stats for 59 step
# Loss = 2.225
# Accuracy = 0.172
# ------------------------------
# train data stats for 60 step
# Loss = 2.280
# Accuracy = 0.156
# ------------------------------
# train data stats for 61 step
# Loss = 2.284
# Accuracy = 0.156
# ------------------------------
# train data stats for 62 step
# Loss = 2.263
# Accuracy = 0.109
# ------------------------------
# train data stats for 63 step
# Loss = 2.244
# Accuracy = 0.141
# ------------------------------
# train data stats for 64 step
# Loss = 2.214
# Accuracy = 0.234
# ------------------------------
# train data stats for 65 step
# Loss = 2.297
# Accuracy = 0.094
# ------------------------------
# train data stats for 66 step
# Loss = 2.308
# Accuracy = 0.062
# ------------------------------
# train data stats for 67 step
# Loss = 2.267
# Accuracy = 0.109
# ------------------------------
# train data stats for 68 step
# Loss = 2.290
# Accuracy = 0.094
# ------------------------------
# train data stats for 69 step
# Loss = 2.280
# Accuracy = 0.141
# ------------------------------
# train data stats for 70 step
# Loss = 2.268
# Accuracy = 0.109
# ------------------------------
# train data stats for 71 step
# Loss = 2.293
# Accuracy = 0.109
# ------------------------------
# train data stats for 72 step
# Loss = 2.285
# Accuracy = 0.125
# ------------------------------
# train data stats for 73 step
# Loss = 2.226
# Accuracy = 0.234
# ------------------------------
# train data stats for 74 step
# Loss = 2.227
# Accuracy = 0.141
# ------------------------------
# train data stats for 75 step
# Loss = 2.218
# Accuracy = 0.219
# ------------------------------
# train data stats for 76 step
# Loss = 2.276
# Accuracy = 0.141
# ------------------------------
# train data stats for 77 step
# Loss = 2.295
# Accuracy = 0.109
# ------------------------------
# train data stats for 78 step
# Loss = 2.294
# Accuracy = 0.141
# ------------------------------
# train data stats for 79 step
# Loss = 2.245
# Accuracy = 0.125
# ------------------------------
# train data stats for 80 step
# Loss = 2.308
# Accuracy = 0.094
# ------------------------------
# train data stats for 81 step
# Loss = 2.296
# Accuracy = 0.156
# ------------------------------
# train data stats for 82 step
# Loss = 2.240
# Accuracy = 0.234
# ------------------------------
# train data stats for 83 step
# Loss = 2.220
# Accuracy = 0.219
# ------------------------------
# train data stats for 84 step
# Loss = 2.281
# Accuracy = 0.109
# ------------------------------
# train data stats for 85 step
# Loss = 2.253
# Accuracy = 0.156
# ------------------------------
# train data stats for 86 step
# Loss = 2.257
# Accuracy = 0.203
# ------------------------------
# train data stats for 87 step
# Loss = 2.274
# Accuracy = 0.094
# ------------------------------
# train data stats for 88 step
# Loss = 2.236
# Accuracy = 0.234
# ------------------------------
# train data stats for 89 step
# Loss = 2.234
# Accuracy = 0.234
# ------------------------------
# train data stats for 90 step
# Loss = 2.244
# Accuracy = 0.156
# ------------------------------
# train data stats for 91 step
# Loss = 2.221
# Accuracy = 0.250
# ------------------------------
# train data stats for 92 step
# Loss = 2.297
# Accuracy = 0.109
# ------------------------------
# train data stats for 93 step
# Loss = 2.270
# Accuracy = 0.172
# ------------------------------
# train data stats for 94 step
# Loss = 2.235
# Accuracy = 0.141
# ------------------------------
# train data stats for 95 step
# Loss = 2.248
# Accuracy = 0.188
# ------------------------------
# train data stats for 96 step
# Loss = 2.224
# Accuracy = 0.188
# ------------------------------
# train data stats for 97 step
# Loss = 2.257
# Accuracy = 0.203
# ------------------------------
# train data stats for 98 step
# Loss = 2.237
# Accuracy = 0.156
# ------------------------------
# train data stats for 99 step
# Loss = 2.242
# Accuracy = 0.234
# ------------------------------
# train data stats for 100 step
# Loss = 2.280
# Accuracy = 0.109
# ------------------------------
# train data stats for 101 step
# Loss = 2.260
# Accuracy = 0.234
# ------------------------------
# train data stats for 102 step
# Loss = 2.254
# Accuracy = 0.156
# ------------------------------
# train data stats for 103 step
# Loss = 2.244
# Accuracy = 0.141
# ------------------------------
# train data stats for 104 step
# Loss = 2.216
# Accuracy = 0.188
# ------------------------------
# train data stats for 105 step
# Loss = 2.219
# Accuracy = 0.203
# ------------------------------
# train data stats for 106 step
# Loss = 2.229
# Accuracy = 0.141
# ------------------------------
# train data stats for 107 step
# Loss = 2.235
# Accuracy = 0.109
# ------------------------------
# train data stats for 108 step
# Loss = 2.255
# Accuracy = 0.109
# ------------------------------
# train data stats for 109 step
# Loss = 2.243
# Accuracy = 0.125
# ------------------------------
# train data stats for 110 step
# Loss = 2.288
# Accuracy = 0.094
# ------------------------------
# train data stats for 111 step
# Loss = 2.226
# Accuracy = 0.141
# ------------------------------
# train data stats for 112 step
# Loss = 2.168
# Accuracy = 0.266
# ------------------------------
# train data stats for 113 step
# Loss = 2.203
# Accuracy = 0.172
# ------------------------------
# train data stats for 114 step
# Loss = 2.202
# Accuracy = 0.250
# ------------------------------
# train data stats for 115 step
# Loss = 2.156
# Accuracy = 0.234
# ------------------------------
# train data stats for 116 step
# Loss = 2.280
# Accuracy = 0.109
# ------------------------------
# train data stats for 117 step
# Loss = 2.277
# Accuracy = 0.094
# ------------------------------
# train data stats for 118 step
# Loss = 2.190
# Accuracy = 0.250
# ------------------------------
# train data stats for 119 step
# Loss = 2.291
# Accuracy = 0.094
# ------------------------------
# train data stats for 120 step
# Loss = 2.232
# Accuracy = 0.125
# ------------------------------
# train data stats for 121 step
# Loss = 2.213
# Accuracy = 0.234
# ------------------------------
# train data stats for 122 step
# Loss = 2.243
# Accuracy = 0.156
# ------------------------------
# train data stats for 123 step
# Loss = 2.226
# Accuracy = 0.188
# ------------------------------
# train data stats for 124 step
# Loss = 2.252
# Accuracy = 0.156
# ------------------------------
# train data stats for 125 step
# Loss = 2.221
# Accuracy = 0.156
# ------------------------------
# train data stats for 126 step
# Loss = 2.208
# Accuracy = 0.219
# ------------------------------
# train data stats for 127 step
# Loss = 2.232
# Accuracy = 0.172
# ------------------------------
# train data stats for 128 step
# Loss = 2.200
# Accuracy = 0.219
# ------------------------------
# train data stats for 129 step
# Loss = 2.217
# Accuracy = 0.203
# ------------------------------
# train data stats for 130 step
# Loss = 2.248
# Accuracy = 0.141
# ------------------------------
# train data stats for 131 step
# Loss = 2.246
# Accuracy = 0.125
# ------------------------------
# train data stats for 132 step
# Loss = 2.186
# Accuracy = 0.234
# ------------------------------
# train data stats for 133 step
# Loss = 2.216
# Accuracy = 0.250
# ------------------------------
# train data stats for 134 step
# Loss = 2.252
# Accuracy = 0.203
# ------------------------------
# train data stats for 135 step
# Loss = 2.220
# Accuracy = 0.172
# ------------------------------
# train data stats for 136 step
# Loss = 2.179
# Accuracy = 0.250
# ------------------------------
# train data stats for 137 step
# Loss = 2.240
# Accuracy = 0.172
# ------------------------------
# train data stats for 138 step
# Loss = 2.250
# Accuracy = 0.078
# ------------------------------
# train data stats for 139 step
# Loss = 2.216
# Accuracy = 0.188
# ------------------------------
# train data stats for 140 step
# Loss = 2.227
# Accuracy = 0.094
# ------------------------------
# train data stats for 141 step
# Loss = 2.199
# Accuracy = 0.188
# ------------------------------
# train data stats for 142 step
# Loss = 2.250
# Accuracy = 0.172
# ------------------------------
# train data stats for 143 step
# Loss = 2.156
# Accuracy = 0.250
# ------------------------------
# train data stats for 144 step
# Loss = 2.245
# Accuracy = 0.156
# ------------------------------
# train data stats for 145 step
# Loss = 2.202
# Accuracy = 0.203
# ------------------------------
# train data stats for 146 step
# Loss = 2.218
# Accuracy = 0.141
# ------------------------------
# train data stats for 147 step
# Loss = 2.210
# Accuracy = 0.203
# ------------------------------
# train data stats for 148 step
# Loss = 2.237
# Accuracy = 0.094
# ------------------------------
# train data stats for 149 step
# Loss = 2.271
# Accuracy = 0.156
# ------------------------------
# train data stats for 150 step
# Loss = 2.228
# Accuracy = 0.234
# ------------------------------
# train data stats for 151 step
# Loss = 2.230
# Accuracy = 0.188
# ------------------------------
# train data stats for 152 step
# Loss = 2.195
# Accuracy = 0.297
# ------------------------------
# train data stats for 153 step
# Loss = 2.207
# Accuracy = 0.203
# ------------------------------
# train data stats for 154 step
# Loss = 2.202
# Accuracy = 0.188
# ------------------------------
# train data stats for 155 step
# Loss = 2.246
# Accuracy = 0.141
# ------------------------------
# train data stats for 156 step
# Loss = 2.212
# Accuracy = 0.219
# ------------------------------
# train data stats for 157 step
# Loss = 2.224
# Accuracy = 0.172
# ------------------------------
# train data stats for 158 step
# Loss = 2.216
# Accuracy = 0.172
# ------------------------------
# train data stats for 159 step
# Loss = 2.205
# Accuracy = 0.203
# ------------------------------
# train data stats for 160 step
# Loss = 2.210
# Accuracy = 0.203
# ------------------------------
# train data stats for 161 step
# Loss = 2.227
# Accuracy = 0.156
# ------------------------------
# train data stats for 162 step
# Loss = 2.189
# Accuracy = 0.219
# ------------------------------
# train data stats for 163 step
# Loss = 2.229
# Accuracy = 0.125
# ------------------------------
# train data stats for 164 step
# Loss = 2.183
# Accuracy = 0.250
# ------------------------------
# train data stats for 165 step
# Loss = 2.244
# Accuracy = 0.188
# ------------------------------
# train data stats for 166 step
# Loss = 2.184
# Accuracy = 0.219
# ------------------------------
# train data stats for 167 step
# Loss = 2.188
# Accuracy = 0.281
# ------------------------------
# train data stats for 168 step
# Loss = 2.171
# Accuracy = 0.141
# ------------------------------
# train data stats for 169 step
# Loss = 2.238
# Accuracy = 0.219
# ------------------------------
# train data stats for 170 step
# Loss = 2.238
# Accuracy = 0.156
# ------------------------------
# train data stats for 171 step
# Loss = 2.176
# Accuracy = 0.188
# ------------------------------
# train data stats for 172 step
# Loss = 2.245
# Accuracy = 0.188
# ------------------------------
# train data stats for 173 step
# Loss = 2.224
# Accuracy = 0.156
# ------------------------------
# train data stats for 174 step
# Loss = 2.255
# Accuracy = 0.250
# ------------------------------
# train data stats for 175 step
# Loss = 2.193
# Accuracy = 0.250
# ------------------------------
# train data stats for 176 step
# Loss = 2.184
# Accuracy = 0.266
# ------------------------------
# train data stats for 177 step
# Loss = 2.206
# Accuracy = 0.219
# ------------------------------
# train data stats for 178 step
# Loss = 2.204
# Accuracy = 0.203
# ------------------------------
# train data stats for 179 step
# Loss = 2.223
# Accuracy = 0.188
# ------------------------------
# train data stats for 180 step
# Loss = 2.223
# Accuracy = 0.109
# ------------------------------
# train data stats for 181 step
# Loss = 2.271
# Accuracy = 0.109
# ------------------------------
# train data stats for 182 step
# Loss = 2.211
# Accuracy = 0.234
# ------------------------------
# train data stats for 183 step
# Loss = 2.217
# Accuracy = 0.203
# ------------------------------
# train data stats for 184 step
# Loss = 2.246
# Accuracy = 0.188
# ------------------------------
# train data stats for 185 step
# Loss = 2.185
# Accuracy = 0.250
# ------------------------------
# train data stats for 186 step
# Loss = 2.194
# Accuracy = 0.219
# ------------------------------
# train data stats for 187 step
# Loss = 2.187
# Accuracy = 0.281
# ------------------------------
# train data stats for 188 step
# Loss = 2.169
# Accuracy = 0.234
# ------------------------------
# train data stats for 189 step
# Loss = 2.181
# Accuracy = 0.219
# ------------------------------
# train data stats for 190 step
# Loss = 2.184
# Accuracy = 0.219
# ------------------------------
# train data stats for 191 step
# Loss = 2.158
# Accuracy = 0.266
# ------------------------------
# train data stats for 192 step
# Loss = 2.215
# Accuracy = 0.172
# ------------------------------
# train data stats for 193 step
# Loss = 2.246
# Accuracy = 0.125
# ------------------------------
# train data stats for 194 step
# Loss = 2.239
# Accuracy = 0.203
# ------------------------------
# train data stats for 195 step
# Loss = 2.210
# Accuracy = 0.188
# ------------------------------
# train data stats for 196 step
# Loss = 2.197
# Accuracy = 0.203
# ------------------------------
# train data stats for 197 step
# Loss = 2.226
# Accuracy = 0.141
# ------------------------------
# train data stats for 198 step
# Loss = 2.256
# Accuracy = 0.172
# ------------------------------
# train data stats for 199 step
# Loss = 2.164
# Accuracy = 0.250
# ------------------------------
# train data stats for 200 step
# Loss = 2.185
# Accuracy = 0.234
# ------------------------------
# train data stats for 201 step
# Loss = 2.181
# Accuracy = 0.141
# ------------------------------
# train data stats for 202 step
# Loss = 2.216
# Accuracy = 0.156
# ------------------------------
# train data stats for 203 step
# Loss = 2.198
# Accuracy = 0.172
# ------------------------------
# train data stats for 204 step
# Loss = 2.146
# Accuracy = 0.234
# ------------------------------
# train data stats for 205 step
# Loss = 2.160
# Accuracy = 0.234
# ------------------------------
# train data stats for 206 step
# Loss = 2.164
# Accuracy = 0.250
# ------------------------------
# train data stats for 207 step
# Loss = 2.153
# Accuracy = 0.234
# ------------------------------
# train data stats for 208 step
# Loss = 2.195
# Accuracy = 0.219
# ------------------------------
# train data stats for 209 step
# Loss = 2.172
# Accuracy = 0.234
# ------------------------------
# train data stats for 210 step
# Loss = 2.281
# Accuracy = 0.125
# ------------------------------
# train data stats for 211 step
# Loss = 2.186
# Accuracy = 0.188
# ------------------------------
# train data stats for 212 step
# Loss = 2.209
# Accuracy = 0.188
# ------------------------------
# train data stats for 213 step
# Loss = 2.257
# Accuracy = 0.172
# ------------------------------
# train data stats for 214 step
# Loss = 2.227
# Accuracy = 0.188
# ------------------------------
# train data stats for 215 step
# Loss = 2.210
# Accuracy = 0.172
# ------------------------------
# train data stats for 216 step
# Loss = 2.160
# Accuracy = 0.234
# ------------------------------
# train data stats for 217 step
# Loss = 2.167
# Accuracy = 0.219
# ------------------------------
# train data stats for 218 step
# Loss = 2.184
# Accuracy = 0.188
# ------------------------------
# train data stats for 219 step
# Loss = 2.220
# Accuracy = 0.219
# ------------------------------
# train data stats for 220 step
# Loss = 2.175
# Accuracy = 0.250
# ------------------------------
# train data stats for 221 step
# Loss = 2.184
# Accuracy = 0.234
# ------------------------------
# train data stats for 222 step
# Loss = 2.159
# Accuracy = 0.297
# ------------------------------
# train data stats for 223 step
# Loss = 2.175
# Accuracy = 0.250
# ------------------------------
# train data stats for 224 step
# Loss = 2.191
# Accuracy = 0.188
# ------------------------------
# train data stats for 225 step
# Loss = 2.147
# Accuracy = 0.234
# ------------------------------
# train data stats for 226 step
# Loss = 2.152
# Accuracy = 0.219
# ------------------------------
# train data stats for 227 step
# Loss = 2.175
# Accuracy = 0.250
# ------------------------------
# train data stats for 228 step
# Loss = 2.182
# Accuracy = 0.219
# ------------------------------
# train data stats for 229 step
# Loss = 2.151
# Accuracy = 0.172
# ------------------------------
# train data stats for 230 step
# Loss = 2.169
# Accuracy = 0.203
# ------------------------------
# train data stats for 231 step
# Loss = 2.195
# Accuracy = 0.188
# ------------------------------
# train data stats for 232 step
# Loss = 2.241
# Accuracy = 0.203
# ------------------------------
# train data stats for 233 step
# Loss = 2.153
# Accuracy = 0.297
# ------------------------------
# train data stats for 234 step
# Loss = 2.200
# Accuracy = 0.172
# ------------------------------
# train data stats for 235 step
# Loss = 2.157
# Accuracy = 0.234
# ------------------------------
# train data stats for 236 step
# Loss = 2.192
# Accuracy = 0.188
# ------------------------------
# train data stats for 237 step
# Loss = 2.233
# Accuracy = 0.156
# ------------------------------
# train data stats for 238 step
# Loss = 2.172
# Accuracy = 0.219
# ------------------------------
# train data stats for 239 step
# Loss = 2.166
# Accuracy = 0.234
# ------------------------------
# train data stats for 240 step
# Loss = 2.158
# Accuracy = 0.188
# ------------------------------
# train data stats for 241 step
# Loss = 2.131
# Accuracy = 0.266
# ------------------------------
# train data stats for 242 step
# Loss = 2.157
# Accuracy = 0.172
# ------------------------------
# train data stats for 243 step
# Loss = 2.207
# Accuracy = 0.203
# ------------------------------
# train data stats for 244 step
# Loss = 2.212
# Accuracy = 0.188
# ------------------------------
# train data stats for 245 step
# Loss = 2.172
# Accuracy = 0.219
# ------------------------------
# train data stats for 246 step
# Loss = 2.190
# Accuracy = 0.203
# ------------------------------
# train data stats for 247 step
# Loss = 2.144
# Accuracy = 0.281
# ------------------------------
# train data stats for 248 step
# Loss = 2.173
# Accuracy = 0.188
# ------------------------------
# train data stats for 249 step
# Loss = 2.197
# Accuracy = 0.234
# ------------------------------
# train data stats for 250 step
# Loss = 2.179
# Accuracy = 0.250
# ------------------------------
# train data stats for 251 step
# Loss = 2.163
# Accuracy = 0.250
# ------------------------------
# train data stats for 252 step
# Loss = 2.149
# Accuracy = 0.188
# ------------------------------
# train data stats for 253 step
# Loss = 2.205
# Accuracy = 0.234
# ------------------------------
# train data stats for 254 step
# Loss = 2.143
# Accuracy = 0.266
# ------------------------------
# train data stats for 255 step
# Loss = 2.163
# Accuracy = 0.250
# ------------------------------
# train data stats for 256 step
# Loss = 2.136
# Accuracy = 0.234
# ------------------------------
# train data stats for 257 step
# Loss = 2.216
# Accuracy = 0.172
# ------------------------------
# train data stats for 258 step
# Loss = 2.122
# Accuracy = 0.234
# ------------------------------
# train data stats for 259 step
# Loss = 2.189
# Accuracy = 0.156
# ------------------------------
# train data stats for 260 step
# Loss = 2.225
# Accuracy = 0.172
# ------------------------------
# train data stats for 261 step
# Loss = 2.132
# Accuracy = 0.281
# ------------------------------
# train data stats for 262 step
# Loss = 2.168
# Accuracy = 0.266
# ------------------------------
# train data stats for 263 step
# Loss = 2.139
# Accuracy = 0.266
# ------------------------------
# train data stats for 264 step
# Loss = 2.169
# Accuracy = 0.266
# ------------------------------
# train data stats for 265 step
# Loss = 2.137
# Accuracy = 0.359
# ------------------------------
# train data stats for 266 step
# Loss = 2.126
# Accuracy = 0.281
# ------------------------------
# train data stats for 267 step
# Loss = 2.159
# Accuracy = 0.156
# ------------------------------
# train data stats for 268 step
# Loss = 2.060
# Accuracy = 0.281
# ------------------------------
# train data stats for 269 step
# Loss = 2.167
# Accuracy = 0.219
# ------------------------------
# train data stats for 270 step
# Loss = 2.160
# Accuracy = 0.156
# ------------------------------
# train data stats for 271 step
# Loss = 2.093
# Accuracy = 0.312
# ------------------------------
# train data stats for 272 step
# Loss = 2.089
# Accuracy = 0.359
# ------------------------------
# train data stats for 273 step
# Loss = 2.142
# Accuracy = 0.203
# ------------------------------
# train data stats for 274 step
# Loss = 2.087
# Accuracy = 0.312
# ------------------------------
# train data stats for 275 step
# Loss = 2.151
# Accuracy = 0.234
# ------------------------------
# train data stats for 276 step
# Loss = 2.204
# Accuracy = 0.125
# ------------------------------
# train data stats for 277 step
# Loss = 2.166
# Accuracy = 0.188
# ------------------------------
# train data stats for 278 step
# Loss = 2.128
# Accuracy = 0.281
# ------------------------------
# train data stats for 279 step
# Loss = 2.161
# Accuracy = 0.219
# ------------------------------
# train data stats for 280 step
# Loss = 2.218
# Accuracy = 0.219
# ------------------------------
# train data stats for 281 step
# Loss = 2.130
# Accuracy = 0.266
# ------------------------------
# train data stats for 282 step
# Loss = 2.186
# Accuracy = 0.156
# ------------------------------
# train data stats for 283 step
# Loss = 2.152
# Accuracy = 0.250
# ------------------------------
# train data stats for 284 step
# Loss = 2.151
# Accuracy = 0.234
# ------------------------------
# train data stats for 285 step
# Loss = 2.147
# Accuracy = 0.234
# ------------------------------
# train data stats for 286 step
# Loss = 2.213
# Accuracy = 0.125
# ------------------------------
# train data stats for 287 step
# Loss = 2.169
# Accuracy = 0.250
# ------------------------------
# train data stats for 288 step
# Loss = 2.108
# Accuracy = 0.250
# ------------------------------
# train data stats for 289 step
# Loss = 2.154
# Accuracy = 0.297
# ------------------------------
# train data stats for 290 step
# Loss = 2.185
# Accuracy = 0.172
# ------------------------------
# train data stats for 291 step
# Loss = 2.146
# Accuracy = 0.266
# ------------------------------
# train data stats for 292 step
# Loss = 2.209
# Accuracy = 0.188
# ------------------------------
# train data stats for 293 step
# Loss = 2.112
# Accuracy = 0.344
# ------------------------------
# train data stats for 294 step
# Loss = 2.157
# Accuracy = 0.188
# ------------------------------
# train data stats for 295 step
# Loss = 2.163
# Accuracy = 0.281
# ------------------------------
# train data stats for 296 step
# Loss = 2.203
# Accuracy = 0.125
# ------------------------------
# train data stats for 297 step
# Loss = 2.191
# Accuracy = 0.172
# ------------------------------
# train data stats for 298 step
# Loss = 2.169
# Accuracy = 0.266
# ------------------------------
# train data stats for 299 step
# Loss = 2.157
# Accuracy = 0.281
# ------------------------------
# train data stats for 300 step
# Loss = 2.074
# Accuracy = 0.281
# ------------------------------
# train data stats for 301 step
# Loss = 2.124
# Accuracy = 0.234
# ------------------------------
# train data stats for 302 step
# Loss = 2.112
# Accuracy = 0.359
# ------------------------------
# train data stats for 303 step
# Loss = 2.149
# Accuracy = 0.219
# ------------------------------
# train data stats for 304 step
# Loss = 2.197
# Accuracy = 0.156
# ------------------------------
# train data stats for 305 step
# Loss = 2.090
# Accuracy = 0.328
# ------------------------------
# train data stats for 306 step
# Loss = 2.105
# Accuracy = 0.297
# ------------------------------
# train data stats for 307 step
# Loss = 2.166
# Accuracy = 0.234
# ------------------------------
# train data stats for 308 step
# Loss = 2.108
# Accuracy = 0.234
# ------------------------------
# train data stats for 309 step
# Loss = 2.185
# Accuracy = 0.219
# ------------------------------
# train data stats for 310 step
# Loss = 2.120
# Accuracy = 0.234
# ------------------------------
# train data stats for 311 step
# Loss = 2.127
# Accuracy = 0.250
# ------------------------------
# train data stats for 312 step
# Loss = 2.117
# Accuracy = 0.312
# ------------------------------
# train data stats for 313 step
# Loss = 2.085
# Accuracy = 0.234
# ------------------------------
# train data stats for 314 step
# Loss = 2.097
# Accuracy = 0.328
# ------------------------------
# train data stats for 315 step
# Loss = 2.165
# Accuracy = 0.219
# ------------------------------
# train data stats for 316 step
# Loss = 2.135
# Accuracy = 0.219
# ------------------------------
# train data stats for 317 step
# Loss = 2.150
# Accuracy = 0.156
# ------------------------------
# train data stats for 318 step
# Loss = 2.172
# Accuracy = 0.234
# ------------------------------
# train data stats for 319 step
# Loss = 2.111
# Accuracy = 0.312
# ------------------------------
# train data stats for 320 step
# Loss = 2.096
# Accuracy = 0.234
# ------------------------------
# train data stats for 321 step
# Loss = 2.229
# Accuracy = 0.156
# ------------------------------
# train data stats for 322 step
# Loss = 2.076
# Accuracy = 0.297
# ------------------------------
# train data stats for 323 step
# Loss = 2.099
# Accuracy = 0.234
# ------------------------------
# train data stats for 324 step
# Loss = 2.111
# Accuracy = 0.297
# ------------------------------
# train data stats for 325 step
# Loss = 2.077
# Accuracy = 0.328
# ------------------------------
# train data stats for 326 step
# Loss = 2.141
# Accuracy = 0.250
# ------------------------------
# train data stats for 327 step
# Loss = 2.129
# Accuracy = 0.188
# ------------------------------
# train data stats for 328 step
# Loss = 2.197
# Accuracy = 0.234
# ------------------------------
# train data stats for 329 step
# Loss = 2.126
# Accuracy = 0.266
# ------------------------------
# train data stats for 330 step
# Loss = 2.169
# Accuracy = 0.188
# ------------------------------
# train data stats for 331 step
# Loss = 2.144
# Accuracy = 0.234
# ------------------------------
# train data stats for 332 step
# Loss = 2.086
# Accuracy = 0.250
# ------------------------------
# train data stats for 333 step
# Loss = 2.169
# Accuracy = 0.250
# ------------------------------
# train data stats for 334 step
# Loss = 2.159
# Accuracy = 0.188
# ------------------------------
# train data stats for 335 step
# Loss = 2.131
# Accuracy = 0.250
# ------------------------------
# train data stats for 336 step
# Loss = 2.154
# Accuracy = 0.234
# ------------------------------
# train data stats for 337 step
# Loss = 2.096
# Accuracy = 0.250
# ------------------------------
# train data stats for 338 step
# Loss = 2.076
# Accuracy = 0.297
# ------------------------------
# train data stats for 339 step
# Loss = 2.198
# Accuracy = 0.219
# ------------------------------
# train data stats for 340 step
# Loss = 2.150
# Accuracy = 0.266
# ------------------------------
# train data stats for 341 step
# Loss = 2.160
# Accuracy = 0.219
# ------------------------------
# train data stats for 342 step
# Loss = 2.104
# Accuracy = 0.234
# ------------------------------
# train data stats for 343 step
# Loss = 2.214
# Accuracy = 0.250
# ------------------------------
# train data stats for 344 step
# Loss = 2.113
# Accuracy = 0.312
# ------------------------------
# train data stats for 345 step
# Loss = 2.016
# Accuracy = 0.328
# ------------------------------
# train data stats for 346 step
# Loss = 2.078
# Accuracy = 0.297
# ------------------------------
# train data stats for 347 step
# Loss = 2.174
# Accuracy = 0.281
# ------------------------------
# train data stats for 348 step
# Loss = 2.152
# Accuracy = 0.266
# ------------------------------
# train data stats for 349 step
# Loss = 2.124
# Accuracy = 0.297
# ------------------------------
# train data stats for 350 step
# Loss = 2.172
# Accuracy = 0.156
# ------------------------------
# train data stats for 351 step
# Loss = 2.191
# Accuracy = 0.109
# ------------------------------
# train data stats for 352 step
# Loss = 2.194
# Accuracy = 0.266
# ------------------------------
# train data stats for 353 step
# Loss = 2.168
# Accuracy = 0.250
# ------------------------------
# train data stats for 354 step
# Loss = 2.168
# Accuracy = 0.250
# ------------------------------
# train data stats for 355 step
# Loss = 2.105
# Accuracy = 0.188
# ------------------------------
# train data stats for 356 step
# Loss = 2.188
# Accuracy = 0.172
# ------------------------------
# train data stats for 357 step
# Loss = 2.128
# Accuracy = 0.281
# ------------------------------
# train data stats for 358 step
# Loss = 2.188
# Accuracy = 0.234
# ------------------------------
# train data stats for 359 step
# Loss = 2.195
# Accuracy = 0.172
# ------------------------------
# train data stats for 360 step
# Loss = 2.115
# Accuracy = 0.281
# ------------------------------
# train data stats for 361 step
# Loss = 2.163
# Accuracy = 0.250
# ------------------------------
# train data stats for 362 step
# Loss = 2.147
# Accuracy = 0.234
# ------------------------------
# train data stats for 363 step
# Loss = 2.066
# Accuracy = 0.219
# ------------------------------
# train data stats for 364 step
# Loss = 2.133
# Accuracy = 0.297
# ------------------------------
# train data stats for 365 step
# Loss = 2.134
# Accuracy = 0.219
# ------------------------------
# train data stats for 366 step
# Loss = 2.119
# Accuracy = 0.250
# ------------------------------
# train data stats for 367 step
# Loss = 2.145
# Accuracy = 0.203
# ------------------------------
# train data stats for 368 step
# Loss = 2.143
# Accuracy = 0.172
# ------------------------------
# train data stats for 369 step
# Loss = 2.114
# Accuracy = 0.266
# ------------------------------
# train data stats for 370 step
# Loss = 2.123
# Accuracy = 0.328
# ------------------------------
# train data stats for 371 step
# Loss = 2.078
# Accuracy = 0.328
# ------------------------------
# train data stats for 372 step
# Loss = 2.068
# Accuracy = 0.328
# ------------------------------
# train data stats for 373 step
# Loss = 2.140
# Accuracy = 0.250
# ------------------------------
# train data stats for 374 step
# Loss = 2.106
# Accuracy = 0.281
# ------------------------------
# train data stats for 375 step
# Loss = 2.115
# Accuracy = 0.234
# ------------------------------
# train data stats for 376 step
# Loss = 2.170
# Accuracy = 0.141
# ------------------------------
# train data stats for 377 step
# Loss = 2.107
# Accuracy = 0.312
# ------------------------------
# train data stats for 378 step
# Loss = 2.060
# Accuracy = 0.359
# ------------------------------
# train data stats for 379 step
# Loss = 2.177
# Accuracy = 0.172
# ------------------------------
# train data stats for 380 step
# Loss = 2.182
# Accuracy = 0.219
# ------------------------------
# train data stats for 381 step
# Loss = 2.142
# Accuracy = 0.234
# ------------------------------
# train data stats for 382 step
# Loss = 2.065
# Accuracy = 0.312
# ------------------------------
# train data stats for 383 step
# Loss = 2.135
# Accuracy = 0.297
# ------------------------------
# train data stats for 384 step
# Loss = 2.115
# Accuracy = 0.234
# ------------------------------
# train data stats for 385 step
# Loss = 2.114
# Accuracy = 0.234
# ------------------------------
# train data stats for 386 step
# Loss = 2.059
# Accuracy = 0.359
# ------------------------------
# train data stats for 387 step
# Loss = 2.146
# Accuracy = 0.266
# ------------------------------
# train data stats for 388 step
# Loss = 2.150
# Accuracy = 0.219
# ------------------------------
# train data stats for 389 step
# Loss = 2.114
# Accuracy = 0.250
# ------------------------------
# train data stats for 390 step
# Loss = 2.118
# Accuracy = 0.203
# ------------------------------
# train data stats for 391 step
# Loss = 2.101
# Accuracy = 0.297
# ------------------------------
# train data stats for 392 step
# Loss = 2.130
# Accuracy = 0.234
# ------------------------------
# train data stats for 393 step
# Loss = 2.136
# Accuracy = 0.219
# ------------------------------
# train data stats for 394 step
# Loss = 2.160
# Accuracy = 0.172
# ------------------------------
# train data stats for 395 step
# Loss = 2.107
# Accuracy = 0.312
# ------------------------------
# train data stats for 396 step
# Loss = 2.097
# Accuracy = 0.266
# ------------------------------
# train data stats for 397 step
# Loss = 2.143
# Accuracy = 0.266
# ------------------------------
# train data stats for 398 step
# Loss = 2.082
# Accuracy = 0.266
# ------------------------------
# train data stats for 399 step
# Loss = 2.154
# Accuracy = 0.188
# ------------------------------
# train data stats for 400 step
# Loss = 2.179
# Accuracy = 0.172
# ------------------------------
# train data stats for 401 step
# Loss = 2.141
# Accuracy = 0.234
# ------------------------------
# train data stats for 402 step
# Loss = 2.027
# Accuracy = 0.359
# ------------------------------
# train data stats for 403 step
# Loss = 2.095
# Accuracy = 0.234
# ------------------------------
# train data stats for 404 step
# Loss = 2.146
# Accuracy = 0.234
# ------------------------------
# train data stats for 405 step
# Loss = 2.136
# Accuracy = 0.250
# ------------------------------
# train data stats for 406 step
# Loss = 2.039
# Accuracy = 0.297
# ------------------------------
# train data stats for 407 step
# Loss = 2.091
# Accuracy = 0.234
# ------------------------------
# train data stats for 408 step
# Loss = 2.083
# Accuracy = 0.266
# ------------------------------
# train data stats for 409 step
# Loss = 2.176
# Accuracy = 0.297
# ------------------------------
# train data stats for 410 step
# Loss = 2.111
# Accuracy = 0.219
# ------------------------------
# train data stats for 411 step
# Loss = 2.109
# Accuracy = 0.219
# ------------------------------
# train data stats for 412 step
# Loss = 2.134
# Accuracy = 0.250
# ------------------------------
# train data stats for 413 step
# Loss = 2.136
# Accuracy = 0.203
# ------------------------------
# train data stats for 414 step
# Loss = 2.133
# Accuracy = 0.156
# ------------------------------
# train data stats for 415 step
# Loss = 2.057
# Accuracy = 0.312
# ------------------------------
# train data stats for 416 step
# Loss = 2.117
# Accuracy = 0.250
# ------------------------------
# train data stats for 417 step
# Loss = 2.085
# Accuracy = 0.250
# ------------------------------
# train data stats for 418 step
# Loss = 2.122
# Accuracy = 0.250
# ------------------------------
# train data stats for 419 step
# Loss = 2.101
# Accuracy = 0.281
# ------------------------------
# train data stats for 420 step
# Loss = 2.064
# Accuracy = 0.328
# ------------------------------
# train data stats for 421 step
# Loss = 2.174
# Accuracy = 0.250
# ------------------------------
# train data stats for 422 step
# Loss = 2.118
# Accuracy = 0.297
# ------------------------------
# train data stats for 423 step
# Loss = 2.141
# Accuracy = 0.172
# ------------------------------
# train data stats for 424 step
# Loss = 2.192
# Accuracy = 0.219
# ------------------------------
# train data stats for 425 step
# Loss = 2.145
# Accuracy = 0.297
# ------------------------------
# train data stats for 426 step
# Loss = 2.124
# Accuracy = 0.234
# ------------------------------
# train data stats for 427 step
# Loss = 2.113
# Accuracy = 0.203
# ------------------------------
# train data stats for 428 step
# Loss = 2.091
# Accuracy = 0.203
# ------------------------------
# train data stats for 429 step
# Loss = 2.114
# Accuracy = 0.094
# ------------------------------
# train data stats for 430 step
# Loss = 2.166
# Accuracy = 0.188
# ------------------------------
# train data stats for 431 step
# Loss = 2.188
# Accuracy = 0.250
# ------------------------------
# train data stats for 432 step
# Loss = 2.077
# Accuracy = 0.312
# ------------------------------
# train data stats for 433 step
# Loss = 2.119
# Accuracy = 0.266
# ------------------------------
# train data stats for 434 step
# Loss = 2.055
# Accuracy = 0.250
# ------------------------------
# train data stats for 435 step
# Loss = 2.151
# Accuracy = 0.188
# ------------------------------
# train data stats for 436 step
# Loss = 2.076
# Accuracy = 0.281
# ------------------------------
# train data stats for 437 step
# Loss = 2.038
# Accuracy = 0.344
# ------------------------------
# train data stats for 438 step
# Loss = 2.164
# Accuracy = 0.188
# ------------------------------
# train data stats for 439 step
# Loss = 2.153
# Accuracy = 0.266
# ------------------------------
# train data stats for 440 step
# Loss = 2.163
# Accuracy = 0.156
# ------------------------------
# train data stats for 441 step
# Loss = 2.072
# Accuracy = 0.219
# ------------------------------
# train data stats for 442 step
# Loss = 2.067
# Accuracy = 0.281
# ------------------------------
# train data stats for 443 step
# Loss = 2.148
# Accuracy = 0.188
# ------------------------------
# train data stats for 444 step
# Loss = 2.125
# Accuracy = 0.188
# ------------------------------
# train data stats for 445 step
# Loss = 2.142
# Accuracy = 0.297
# ------------------------------
# train data stats for 446 step
# Loss = 2.204
# Accuracy = 0.281
# ------------------------------
# train data stats for 447 step
# Loss = 2.103
# Accuracy = 0.297
# ------------------------------
# train data stats for 448 step
# Loss = 2.140
# Accuracy = 0.281
# ------------------------------
# train data stats for 449 step
# Loss = 2.175
# Accuracy = 0.250
# ------------------------------
# train data stats for 450 step
# Loss = 2.115
# Accuracy = 0.172
# ------------------------------
# train data stats for 451 step
# Loss = 2.070
# Accuracy = 0.297
# ------------------------------
# train data stats for 452 step
# Loss = 2.152
# Accuracy = 0.203
# ------------------------------
# train data stats for 453 step
# Loss = 2.121
# Accuracy = 0.219
# ------------------------------
# train data stats for 454 step
# Loss = 2.075
# Accuracy = 0.266
# ------------------------------
# train data stats for 455 step
# Loss = 2.083
# Accuracy = 0.297
# ------------------------------
# train data stats for 456 step
# Loss = 2.091
# Accuracy = 0.312
# ------------------------------
# train data stats for 457 step
# Loss = 2.095
# Accuracy = 0.234
# ------------------------------
# train data stats for 458 step
# Loss = 2.101
# Accuracy = 0.219
# ------------------------------
# train data stats for 459 step
# Loss = 2.060
# Accuracy = 0.344
# ------------------------------
# train data stats for 460 step
# Loss = 2.117
# Accuracy = 0.250
# ------------------------------
# train data stats for 461 step
# Loss = 2.134
# Accuracy = 0.312
# ------------------------------
# train data stats for 462 step
# Loss = 2.120
# Accuracy = 0.281
# ------------------------------
# train data stats for 463 step
# Loss = 2.047
# Accuracy = 0.250
# ------------------------------
# train data stats for 464 step
# Loss = 2.151
# Accuracy = 0.266
# ------------------------------
# train data stats for 465 step
# Loss = 2.075
# Accuracy = 0.281
# ------------------------------
# train data stats for 466 step
# Loss = 2.026
# Accuracy = 0.266
# ------------------------------
# train data stats for 467 step
# Loss = 2.182
# Accuracy = 0.188
# ------------------------------
# train data stats for 468 step
# Loss = 2.080
# Accuracy = 0.281
# ------------------------------
# train data stats for 469 step
# Loss = 2.095
# Accuracy = 0.234
# ------------------------------
# train data stats for 470 step
# Loss = 2.122
# Accuracy = 0.266
# ------------------------------
# train data stats for 471 step
# Loss = 2.057
# Accuracy = 0.250
# ------------------------------
# train data stats for 472 step
# Loss = 2.150
# Accuracy = 0.219
# ------------------------------
# train data stats for 473 step
# Loss = 2.113
# Accuracy = 0.281
# ------------------------------
# train data stats for 474 step
# Loss = 2.141
# Accuracy = 0.281
# ------------------------------
# train data stats for 475 step
# Loss = 2.115
# Accuracy = 0.250
# ------------------------------
# train data stats for 476 step
# Loss = 2.151
# Accuracy = 0.328
# ------------------------------
# train data stats for 477 step
# Loss = 2.127
# Accuracy = 0.234
# ------------------------------
# train data stats for 478 step
# Loss = 2.110
# Accuracy = 0.312
# ------------------------------
# train data stats for 479 step
# Loss = 2.162
# Accuracy = 0.156
# ------------------------------
# train data stats for 480 step
# Loss = 2.107
# Accuracy = 0.297
# ------------------------------
# train data stats for 481 step
# Loss = 2.211
# Accuracy = 0.156
# ------------------------------
# train data stats for 482 step
# Loss = 2.067
# Accuracy = 0.359
# ------------------------------
# train data stats for 483 step
# Loss = 2.174
# Accuracy = 0.188
# ------------------------------
# train data stats for 484 step
# Loss = 2.084
# Accuracy = 0.328
# ------------------------------
# train data stats for 485 step
# Loss = 2.062
# Accuracy = 0.281
# ------------------------------
# train data stats for 486 step
# Loss = 2.066
# Accuracy = 0.297
# ------------------------------
# train data stats for 487 step
# Loss = 2.156
# Accuracy = 0.203
# ------------------------------
# train data stats for 488 step
# Loss = 2.020
# Accuracy = 0.375
# ------------------------------
# train data stats for 489 step
# Loss = 2.056
# Accuracy = 0.344
# ------------------------------
# train data stats for 490 step
# Loss = 2.032
# Accuracy = 0.281
# ------------------------------
# train data stats for 491 step
# Loss = 2.040
# Accuracy = 0.297
# ------------------------------
# train data stats for 492 step
# Loss = 2.111
# Accuracy = 0.281
# ------------------------------
# train data stats for 493 step
# Loss = 2.168
# Accuracy = 0.234
# ------------------------------
# train data stats for 494 step
# Loss = 2.106
# Accuracy = 0.281
# ------------------------------
# train data stats for 495 step
# Loss = 2.069
# Accuracy = 0.266
# ------------------------------
# train data stats for 496 step
# Loss = 2.055
# Accuracy = 0.312
# ------------------------------
# train data stats for 497 step
# Loss = 2.036
# Accuracy = 0.312
# ------------------------------
# train data stats for 498 step
# Loss = 2.063
# Accuracy = 0.281
# ------------------------------
# train data stats for 499 step
# Loss = 2.074
# Accuracy = 0.297
# ------------------------------
# train data stats for 500 step
# Loss = 2.064
# Accuracy = 0.297
# ------------------------------
# train data stats for 501 step
# Loss = 2.100
# Accuracy = 0.297
# ------------------------------
# train data stats for 502 step
# Loss = 2.087
# Accuracy = 0.219
# ------------------------------
# train data stats for 503 step
# Loss = 2.102
# Accuracy = 0.203
# ------------------------------
# train data stats for 504 step
# Loss = 2.005
# Accuracy = 0.344
# ------------------------------
# train data stats for 505 step
# Loss = 2.043
# Accuracy = 0.312
# ------------------------------
# train data stats for 506 step
# Loss = 2.163
# Accuracy = 0.250
# ------------------------------
# train data stats for 507 step
# Loss = 2.060
# Accuracy = 0.281
# ------------------------------
# train data stats for 508 step
# Loss = 1.971
# Accuracy = 0.344
# ------------------------------
# train data stats for 509 step
# Loss = 2.127
# Accuracy = 0.234
# ------------------------------
# train data stats for 510 step
# Loss = 2.087
# Accuracy = 0.344
# ------------------------------
# train data stats for 511 step
# Loss = 2.095
# Accuracy = 0.281
# ------------------------------
# train data stats for 512 step
# Loss = 2.168
# Accuracy = 0.156
# ------------------------------
# train data stats for 513 step
# Loss = 2.130
# Accuracy = 0.234
# ------------------------------
# train data stats for 514 step
# Loss = 2.022
# Accuracy = 0.297
# ------------------------------
# train data stats for 515 step
# Loss = 2.142
# Accuracy = 0.250
# ------------------------------
# train data stats for 516 step
# Loss = 2.196
# Accuracy = 0.203
# ------------------------------
# train data stats for 517 step
# Loss = 2.090
# Accuracy = 0.266
# ------------------------------
# train data stats for 518 step
# Loss = 2.129
# Accuracy = 0.250
# ------------------------------
# train data stats for 519 step
# Loss = 2.102
# Accuracy = 0.234
# ------------------------------
# train data stats for 520 step
# Loss = 2.014
# Accuracy = 0.312
# ------------------------------
# train data stats for 521 step
# Loss = 2.117
# Accuracy = 0.188
# ------------------------------
# train data stats for 522 step
# Loss = 2.169
# Accuracy = 0.234
# ------------------------------
# train data stats for 523 step
# Loss = 2.110
# Accuracy = 0.250
# ------------------------------
# train data stats for 524 step
# Loss = 2.102
# Accuracy = 0.219
# ------------------------------
# train data stats for 525 step
# Loss = 2.088
# Accuracy = 0.234
# ------------------------------
# train data stats for 526 step
# Loss = 2.133
# Accuracy = 0.219
# ------------------------------
# train data stats for 527 step
# Loss = 1.999
# Accuracy = 0.344
# ------------------------------
# ...
# train data stats for 760 step
# Loss = 2.055
# Accuracy = 0.250
# ------------------------------
# train data stats for 761 step
# Loss = 1.984
# Accuracy = 0.281
# ------------------------------
# train data stats for 762 step
# Loss = 2.048
# Accuracy = 0.266
# ------------------------------
# train data stats for 763 step
# Loss = 2.116
# Accuracy = 0.203
# ------------------------------
# train data stats for 764 step
# Loss = 2.039
# Accuracy = 0.234
# ------------------------------
# train data stats for 765 step
# Loss = 2.033
# Accuracy = 0.312
# ------------------------------
# train data stats for 766 step
# Loss = 2.014
# Accuracy = 0.250
# ------------------------------
# train data stats for 767 step
# Loss = 2.035
# Accuracy = 0.266
# ------------------------------
# train data stats for 768 step
# Loss = 2.082
# Accuracy = 0.266
# ------------------------------
# train data stats for 769 step
# Loss = 2.089
# Accuracy = 0.250
# ------------------------------
# train data stats for 770 step
# Loss = 2.060
# Accuracy = 0.266
# ------------------------------
# train data stats for 771 step
# Loss = 2.062
# Accuracy = 0.328
# ------------------------------
# train data stats for 772 step
# Loss = 1.994
# Accuracy = 0.312
# ------------------------------
# train data stats for 773 step
# Loss = 2.102
# Accuracy = 0.297
# ------------------------------
# train data stats for 774 step
# Loss = 1.994
# Accuracy = 0.312
# ------------------------------
# train data stats for 775 step
# Loss = 2.104
# Accuracy = 0.172
# ------------------------------
# train data stats for 776 step
# Loss = 2.075
# Accuracy = 0.297
# ------------------------------
# train data stats for 777 step
# Loss = 2.138
# Accuracy = 0.281
# ------------------------------
# train data stats for 778 step
# Loss = 1.978
# Accuracy = 0.234
# ------------------------------
# train data stats for 779 step
# Loss = 1.917
# Accuracy = 0.375
# ------------------------------
# train data stats for 780 step
# Loss = 2.071
# Accuracy = 0.312
# ------------------------------
# valid data stats for 0 step
# Loss = 2.025
# Accuracy = 0.328
# ------------------------------
# valid data stats for 1 step
# Loss = 2.099
# Accuracy = 0.266
# ------------------------------
# valid data stats for 2 step
# Loss = 2.001
# Accuracy = 0.297
# ------------------------------
# valid data stats for 3 step
# Loss = 2.071
# Accuracy = 0.234
# ------------------------------
# valid data stats for 4 step
# Loss = 2.046
# Accuracy = 0.266
# ------------------------------
# valid data stats for 5 step
# Loss = 1.972
# Accuracy = 0.328
# ------------------------------
# valid data stats for 6 step
# Loss = 1.962
# Accuracy = 0.359
# ------------------------------
# valid data stats for 7 step
# Loss = 2.079
# Accuracy = 0.281
# ------------------------------
# valid data stats for 8 step
# Loss = 2.049
# Accuracy = 0.203
# ------------------------------
# valid data stats for 9 step
# Loss = 1.977
# Accuracy = 0.312
# ------------------------------
# valid data stats for 10 step
# Loss = 2.031
# Accuracy = 0.281
# ------------------------------
# valid data stats for 11 step
# Loss = 2.070
# Accuracy = 0.312
# ------------------------------
# valid data stats for 12 step
# Loss = 2.029
# Accuracy = 0.203
# ------------------------------
# valid data stats for 13 step
# Loss = 2.030
# Accuracy = 0.219
# ------------------------------
# valid data stats for 14 step
# Loss = 2.039
# Accuracy = 0.297
# ------------------------------
# valid data stats for 15 step
# Loss = 2.122
# Accuracy = 0.156
# ------------------------------
# valid data stats for 16 step
# Loss = 2.153
# Accuracy = 0.266
# ------------------------------
# valid data stats for 17 step
# Loss = 2.111
# Accuracy = 0.234
# ------------------------------
# valid data stats for 18 step
# Loss = 2.004
# Accuracy = 0.359
# ------------------------------
# valid data stats for 19 step
# Loss = 1.966
# Accuracy = 0.297
# ------------------------------
# valid data stats for 20 step
# Loss = 2.146
# Accuracy = 0.188
# ------------------------------
# valid data stats for 21 step
# Loss = 2.076
# Accuracy = 0.281
# ------------------------------
# valid data stats for 22 step
# Loss = 2.016
# Accuracy = 0.266
# ------------------------------
# valid data stats for 23 step
# Loss = 1.998
# Accuracy = 0.297
# ------------------------------
# valid data stats for 24 step
# Loss = 2.018
# Accuracy = 0.297
# ------------------------------
# valid data stats for 25 step
# Loss = 2.070
# Accuracy = 0.328
# ------------------------------
# valid data stats for 26 step
# Loss = 2.140
# Accuracy = 0.203
# ------------------------------
# valid data stats for 27 step
# Loss = 2.053
# Accuracy = 0.266
# ------------------------------
# valid data stats for 28 step
# Loss = 1.925
# Accuracy = 0.438
# ------------------------------
# valid data stats for 29 step
# Loss = 2.048
# Accuracy = 0.281
# ------------------------------
# valid data stats for 30 step
# Loss = 2.008
# Accuracy = 0.359
# ------------------------------
# valid data stats for 31 step
# Loss = 2.016
# Accuracy = 0.250
# ------------------------------
# valid data stats for 32 step
# Loss = 1.998
# Accuracy = 0.344
# ------------------------------
# valid data stats for 33 step
# Loss = 1.990
# Accuracy = 0.344
# ------------------------------
# valid data stats for 34 step
# Loss = 2.022
# Accuracy = 0.266
# ------------------------------
# valid data stats for 35 step
# Loss = 2.001
# Accuracy = 0.219
# ------------------------------
# valid data stats for 36 step
# Loss = 2.015
# Accuracy = 0.281
# ------------------------------
# valid data stats for 37 step
# Loss = 2.025
# Accuracy = 0.297
# ------------------------------
# valid data stats for 38 step
# Loss = 2.007
# Accuracy = 0.281
# ------------------------------
# valid data stats for 39 step
# Loss = 1.986
# Accuracy = 0.281
# ------------------------------
# valid data stats for 40 step
# Loss = 2.017
# Accuracy = 0.359
# ------------------------------
# valid data stats for 41 step
# Loss = 2.060
# Accuracy = 0.312
# ------------------------------
# valid data stats for 42 step
# Loss = 2.045
# Accuracy = 0.375
# ------------------------------
# valid data stats for 43 step
# Loss = 2.011
# Accuracy = 0.344
# ------------------------------
# valid data stats for 44 step
# Loss = 2.066
# Accuracy = 0.234
# ------------------------------
# valid data stats for 45 step
# Loss = 2.090
# Accuracy = 0.266
# ------------------------------
# valid data stats for 46 step
# Loss = 1.982
# Accuracy = 0.312
# ------------------------------
# valid data stats for 47 step
# Loss = 2.030
# Accuracy = 0.297
# ------------------------------
# valid data stats for 48 step
# Loss = 2.036
# Accuracy = 0.297
# ------------------------------
# valid data stats for 49 step
# Loss = 2.085
# Accuracy = 0.328
# ------------------------------
# valid data stats for 50 step
# Loss = 2.041
# Accuracy = 0.250
# ------------------------------
# valid data stats for 51 step
# Loss = 2.088
# Accuracy = 0.328
# ------------------------------
# valid data stats for 52 step
# Loss = 2.058
# Accuracy = 0.266
# ------------------------------
# valid data stats for 53 step
# Loss = 2.029
# Accuracy = 0.250
# ------------------------------
# valid data stats for 54 step
# Loss = 2.055
# Accuracy = 0.312
# ------------------------------
# valid data stats for 55 step
# Loss = 2.085
# Accuracy = 0.250
# ------------------------------
# valid data stats for 56 step
# Loss = 1.944
# Accuracy = 0.391
# ------------------------------
# valid data stats for 57 step
# Loss = 2.147
# Accuracy = 0.219
# ------------------------------
# valid data stats for 58 step
# Loss = 1.999
# Accuracy = 0.312
# ------------------------------
# valid data stats for 59 step
# Loss = 2.029
# Accuracy = 0.344
# ------------------------------
# valid data stats for 60 step
# Loss = 1.975
# Accuracy = 0.297
# ------------------------------
# valid data stats for 61 step
# Loss = 2.078
# Accuracy = 0.297
# ------------------------------
# valid data stats for 62 step
# Loss = 2.028
# Accuracy = 0.250
# ------------------------------
# valid data stats for 63 step
# Loss = 2.059
# Accuracy = 0.203
# ------------------------------
# valid data stats for 64 step
# Loss = 2.039
# Accuracy = 0.234
# ------------------------------
# valid data stats for 65 step
# Loss = 1.997
# Accuracy = 0.266
# ------------------------------
# valid data stats for 66 step
# Loss = 2.079
# Accuracy = 0.203
# ------------------------------
# valid data stats for 67 step
# Loss = 1.881
# Accuracy = 0.422
# ------------------------------
# valid data stats for 68 step
# Loss = 2.071
# Accuracy = 0.250
# ------------------------------
# valid data stats for 69 step
# Loss = 2.006
# Accuracy = 0.297
# ------------------------------
# valid data stats for 70 step
# Loss = 2.042
# Accuracy = 0.344
# ------------------------------
# valid data stats for 71 step
# Loss = 2.020
# Accuracy = 0.250
# ------------------------------
# valid data stats for 72 step
# Loss = 2.052
# Accuracy = 0.328
# ------------------------------
# valid data stats for 73 step
# Loss = 2.067
# Accuracy = 0.297
# ------------------------------
# valid data stats for 74 step
# Loss = 2.020
# Accuracy = 0.281
# ------------------------------
# valid data stats for 75 step
# Loss = 1.905
# Accuracy = 0.406
# ------------------------------
# valid data stats for 76 step
# Loss = 2.149
# Accuracy = 0.234
# ------------------------------
# valid data stats for 77 step
# Loss = 2.029
# Accuracy = 0.328
# ------------------------------
# valid data stats for 78 step
# Loss = 1.983
# Accuracy = 0.344
# ------------------------------
# valid data stats for 79 step
# Loss = 2.087
# Accuracy = 0.250
# ------------------------------
# valid data stats for 80 step
# Loss = 1.948
# Accuracy = 0.469
# ------------------------------
# valid data stats for 81 step
# Loss = 2.084
# Accuracy = 0.250
# ------------------------------
# valid data stats for 82 step
# Loss = 2.067
# Accuracy = 0.203
# ------------------------------
# valid data stats for 83 step
# Loss = 2.023
# Accuracy = 0.203
# ------------------------------
# valid data stats for 84 step
# Loss = 2.070
# Accuracy = 0.172
# ------------------------------
# valid data stats for 85 step
# Loss = 2.095
# Accuracy = 0.203
# ------------------------------
# valid data stats for 86 step
# Loss = 1.959
# Accuracy = 0.422
# ------------------------------
# valid data stats for 87 step
# Loss = 1.934
# Accuracy = 0.438
# ------------------------------
# valid data stats for 88 step
# Loss = 2.022
# Accuracy = 0.312
# ------------------------------
# valid data stats for 89 step
# Loss = 2.112
# Accuracy = 0.109
# ------------------------------
# valid data stats for 90 step
# Loss = 2.035
# Accuracy = 0.312
# ------------------------------
# valid data stats for 91 step
# Loss = 2.103
# Accuracy = 0.266
# ------------------------------
# valid data stats for 92 step
# Loss = 1.996
# Accuracy = 0.328
# ------------------------------
# valid data stats for 93 step
# Loss = 2.012
# Accuracy = 0.359
# ------------------------------
# valid data stats for 94 step
# Loss = 2.037
# Accuracy = 0.359
# ------------------------------
# valid data stats for 95 step
# Loss = 2.066
# Accuracy = 0.203
# ------------------------------
# valid data stats for 96 step
# Loss = 2.005
# Accuracy = 0.328
# ------------------------------
# valid data stats for 97 step
# Loss = 1.976
# Accuracy = 0.219
# ------------------------------
# valid data stats for 98 step
# Loss = 2.082
# Accuracy = 0.250
# ------------------------------
# valid data stats for 99 step
# Loss = 2.086
# Accuracy = 0.266
# ------------------------------
# valid data stats for 100 step
# Loss = 2.093
# Accuracy = 0.219
# ------------------------------
# valid data stats for 101 step
# Loss = 2.026
# Accuracy = 0.234
# ------------------------------
# valid data stats for 102 step
# Loss = 1.981
# Accuracy = 0.328
# ------------------------------
# valid data stats for 103 step
# Loss = 1.988
# Accuracy = 0.328
# ------------------------------
# valid data stats for 104 step
# Loss = 2.064
# Accuracy = 0.234
# ------------------------------
# valid data stats for 105 step
# Loss = 2.076
# Accuracy = 0.266
# ------------------------------
# valid data stats for 106 step
# Loss = 1.961
# Accuracy = 0.406
# ------------------------------
# valid data stats for 107 step
# Loss = 2.047
# Accuracy = 0.312
# ------------------------------
# valid data stats for 108 step
# Loss = 1.957
# Accuracy = 0.344
# ------------------------------
# valid data stats for 109 step
# Loss = 2.062
# Accuracy = 0.297
# ------------------------------
# valid data stats for 110 step
# Loss = 2.064
# Accuracy = 0.297
# ------------------------------
# valid data stats for 111 step
# Loss = 2.094
# Accuracy = 0.188
# ------------------------------
# valid data stats for 112 step
# Loss = 2.022
# Accuracy = 0.359
# ------------------------------
# valid data stats for 113 step
# Loss = 2.047
# Accuracy = 0.266
# ------------------------------
# valid data stats for 114 step
# Loss = 2.019
# Accuracy = 0.250
# ------------------------------
# valid data stats for 115 step
# Loss = 2.027
# Accuracy = 0.281
# ------------------------------
# valid data stats for 116 step
# Loss = 2.182
# Accuracy = 0.234
# ------------------------------
# valid data stats for 117 step
# Loss = 1.904
# Accuracy = 0.359
# ------------------------------
# valid data stats for 118 step
# Loss = 2.074
# Accuracy = 0.250
# ------------------------------
# valid data stats for 119 step
# Loss = 2.096
# Accuracy = 0.266
# ------------------------------
# valid data stats for 120 step
# Loss = 2.040
# Accuracy = 0.266
# ------------------------------
# valid data stats for 121 step
# Loss = 2.008
# Accuracy = 0.250
# ------------------------------
# valid data stats for 122 step
# Loss = 2.067
# Accuracy = 0.344
# ------------------------------
# valid data stats for 123 step
# Loss = 2.078
# Accuracy = 0.266
# ------------------------------
# valid data stats for 124 step
# Loss = 2.019
# Accuracy = 0.359
# ------------------------------
# valid data stats for 125 step
# Loss = 2.092
# Accuracy = 0.250
# ------------------------------
# valid data stats for 126 step
# Loss = 2.012
# Accuracy = 0.297
# ------------------------------
# valid data stats for 127 step
# Loss = 2.107
# Accuracy = 0.328
# ------------------------------
# valid data stats for 128 step
# Loss = 2.005
# Accuracy = 0.328
# ------------------------------
# valid data stats for 129 step
# Loss = 2.083
# Accuracy = 0.234
# ------------------------------
# valid data stats for 130 step
# Loss = 2.134
# Accuracy = 0.266
# ------------------------------
# valid data stats for 131 step
# Loss = 1.996
# Accuracy = 0.297
# ------------------------------
# valid data stats for 132 step
# Loss = 1.977
# Accuracy = 0.453
# ------------------------------
# valid data stats for 133 step
# Loss = 2.149
# Accuracy = 0.234
# ------------------------------
# valid data stats for 134 step
# Loss = 1.970
# Accuracy = 0.359
# ------------------------------
# valid data stats for 135 step
# Loss = 2.018
# Accuracy = 0.328
# ------------------------------
# valid data stats for 136 step
# Loss = 1.939
# Accuracy = 0.344
# ------------------------------
# valid data stats for 137 step
# Loss = 2.032
# Accuracy = 0.281
# ------------------------------
# valid data stats for 138 step
# Loss = 2.011
# Accuracy = 0.344
# ------------------------------
# valid data stats for 139 step
# Loss = 2.125
# Accuracy = 0.250
# ------------------------------
# valid data stats for 140 step
# Loss = 1.979
# Accuracy = 0.312
# ------------------------------
# valid data stats for 141 step
# Loss = 2.065
# Accuracy = 0.250
# ------------------------------
# valid data stats for 142 step
# Loss = 2.015
# Accuracy = 0.312
# ------------------------------
# valid data stats for 143 step
# Loss = 2.057
# Accuracy = 0.250
# ------------------------------
# valid data stats for 144 step
# Loss = 2.079
# Accuracy = 0.203
# ------------------------------
# valid data stats for 145 step
# Loss = 2.091
# Accuracy = 0.203
# ------------------------------
# valid data stats for 146 step
# Loss = 2.070
# Accuracy = 0.219
# ------------------------------
# valid data stats for 147 step
# Loss = 1.985
# Accuracy = 0.328
# ------------------------------
# valid data stats for 148 step
# Loss = 2.041
# Accuracy = 0.281
# ------------------------------
# valid data stats for 149 step
# Loss = 2.078
# Accuracy = 0.297
# ------------------------------
# valid data stats for 150 step
# Loss = 2.049
# Accuracy = 0.312
# ------------------------------
# valid data stats for 151 step
# Loss = 2.048
# Accuracy = 0.328
# ------------------------------
# valid data stats for 152 step
# Loss = 2.069
# Accuracy = 0.203
# ------------------------------
# valid data stats for 153 step
# Loss = 2.090
# Accuracy = 0.219
# ------------------------------
# valid data stats for 154 step
# Loss = 2.045
# Accuracy = 0.344
# ------------------------------
# valid data stats for 155 step
# Loss = 2.021
# Accuracy = 0.375
# ------------------------------

# %%
softmax_stats.plot_by_epoch()

# %%
softmax_stats.summary()
# Out:
# Epoch 01      loss       acc
# train     2.140750  0.234815
# valid     2.038421  0.288462

# %%
softmax_stats.plot_by_batch(block_len=10)

# %% [markdown]
# ## Vícevrstvý perceptron

# %% [markdown]
# Teď, když máme modularizovanou lineární vrstvu, můžeme si jich vytvořit více a začít je za sebe řetězit. K tomu, abychom vytvořili vícevrstvou síť, však potřebujeme mezi jednotlivé lineární vrstvy ještě přidat nějakou nelineární aktivační funkci. Více lineárních vrstev za sebou totiž dohromady tvoří stále pouze lineární funkci, byť se specifickou faktorizací parametrů.
#
# Nejjednodušší vícevrstvá síť je dvouvrstvý perceptron (perceptron s jednou skrytou vrstvou). Model je:
# 1. $s_1 = W_1x + b_1$
# 2. $h = f(x)$
# 3. $s_2 = W_2h + b_2$
#
# kde $f$ je nějaká nelinearita.

# %% [markdown]
# ### Sigmoid funkce

# %% [markdown]
# Historicky populární volbou nelinearity vycházející z biologického modelu neuronů je sigmoida. Vypadá následovně:
#
#
# **Dopředný průchod**
# $$h = \frac{1}{1 + \exp(-s)}$$
#
# kde $s$ je vstupní "skóre" a $h$ je výsledná skrytá ("hidden") reprezentace.
#
# **Zpětný průchod**
# $$\frac{\partial L}{\partial s} = \frac{\partial L}{\partial h} h (1 - h)$$

# %%
class Sigmoid(Layer):
    
    def __init__(self):
        super().__init__()
    
    def forward(self, score):
        
        hidden = 1 / (1 + torch.exp(-score))

        self._cache = {
            'hidden': hidden
        }
        
        return hidden

    def backward(self, dhidden):

        h = self._cache['hidden']
        dscore = dhidden * h * (1-h)
        dparams = {}
        
        return dscore, dparams

# %%
# overime na male davce
score = torch.randn(10, 3)

# "simulace" prichoziho gradientu, ktery ma vrstva dale propagovat
dhidden = torch.randn(10, 3)

# instance vrstvy
sigmoid_layer = SigmoidLayer()

# jelikoz sigmoida nema zadne parametry, kontrolovat se bude pouze gradient na vstup
neural.check_gradients(sigmoid_layer, score, dhidden);
# Out:
# dinput1 error:  1.3699804079092068e-11

# %% [markdown]
# ### Definice modelu vícevrstvého perceptronu
#
# Celý model složený z více vrstev se bude chovat jako jediná vrstva provádějící komplexnější operaci.

# %%
class TwoLayerPerceptron(Layer):
    
    def __init__(self, input_dim, hidden_dim, output_dim, weight_scale=1e-3):
        super().__init__()
        
        #################################################################
        # ZDE DOPLNIT
        
        self.l1 = Linear(input_dim, hidden_dim)
        self.sigm = Sigmoid()
        self.l2 = Linear(hidden_dim, output_dim)
        self.softMax = SoftmaxCrossEntropyLayer(average=True)
        
        self.params = {
            'weights1': self.l1.params['weights'],
            'bias1': self.l1.params['bias'],
            'weights2': self.l2.params['weights'],
            'bias2': self.l2.params['bias'],
        }
    
    def forward(self, inputs):
        self.l1.params['weights'] = self.params['weights1']
        self.l1.params['bias'] = self.params['bias1']
        self.l2.params['weights'] = self.params['weights2']
        self.l2.params['bias'] = self.params['bias2']

        l1 = self.l1.forward(inputs)
        score1 = self.sigm.forward(l1)
        l2 = self.l2.forward(score1)

        return l2
    
    def backward(self, dscore2):
        dl2_i, dl2  = self.l2.backward(dscore2)
        dsigm1 = self.sigm.backward(dl2_i)[0]
        dl1_i, dl1 = self.l1.backward(dsigm1)

        dinputs = dl1_i

        dparams = {
            'weights1': dl1['weights'],
            'bias1': dl1['bias'],
            'weights2': dl2['weights'],
            'bias2': dl2['bias'],
        }
        
        #################################################################
        
        return dinputs, dparams

# %%
# overime na male davce
inputs = torch.randn(10, 5)

# "simulace" prichoziho gradientu, ktery ma vrstva dale propagovat
dscore2 = torch.randn(10, 3)

# instance vrstvy
two_layer_perc = TwoLayerPerceptron(5, 3, 3)

# jelikoz sigmoida nema zadne parametry, kontrolovat se bude pouze gradient na vstup
neural.check_gradients(two_layer_perc, inputs, dscore2);
# Out:
# dinput1 error:  7.694740653123262e-10
# dweights1 error:  2.500153089074111e-09
# dbias1 error:  1.0394278956501466e-11
# dweights2 error:  1.1919092418323944e-11
# dbias2 error:  1.6845052831534799e-12

# %% [markdown]
# ### Trénování vícevrstvého perceptronu

# %%
tlp_model = TwoLayerPerceptron(X_train.shape[1], 1024, torch.unique(y_train).shape[0])
sce = SoftmaxCrossEntropy(average=True)

train_loader = BatchLoader(X_train, y_train, 64, 'train', shuffle=True)
valid_loader = BatchLoader(X_valid, y_valid, 64, 'valid', shuffle=True)

optimizer = StochasticGradientDescent(tlp_model.params, learning_rate=0.002, weight_decay_l2=0.01)

tlp_stats = Stats()

# %%
for ep in range(10):
    tlp_stats.new_epoch()
    neural.train(tlp_model, sce, train_loader, optimizer, tlp_stats)
    neural.validate(tlp_model, sce, valid_loader, tlp_stats)
# Out:
# train data stats for 0 step
# Loss = 2.294
# Accuracy = 0.109
# ------------------------------
# train data stats for 1 step
# Loss = 2.369
# Accuracy = 0.094
# ------------------------------
# train data stats for 2 step
# Loss = 2.355
# Accuracy = 0.094
# ------------------------------
# train data stats for 3 step
# Loss = 2.413
# Accuracy = 0.062
# ------------------------------
# train data stats for 4 step
# Loss = 2.407
# Accuracy = 0.094
# ------------------------------
# train data stats for 5 step
# Loss = 2.321
# Accuracy = 0.156
# ------------------------------
# train data stats for 6 step
# Loss = 2.349
# Accuracy = 0.047
# ------------------------------
# train data stats for 7 step
# Loss = 2.250
# Accuracy = 0.109
# ------------------------------
# train data stats for 8 step
# Loss = 2.311
# Accuracy = 0.109
# ------------------------------
# train data stats for 9 step
# Loss = 2.328
# Accuracy = 0.047
# ------------------------------
# train data stats for 10 step
# Loss = 2.310
# Accuracy = 0.156
# ------------------------------
# train data stats for 11 step
# Loss = 2.350
# Accuracy = 0.094
# ------------------------------
# train data stats for 12 step
# Loss = 2.304
# Accuracy = 0.094
# ------------------------------
# train data stats for 13 step
# Loss = 2.315
# Accuracy = 0.125
# ------------------------------
# train data stats for 14 step
# Loss = 2.283
# Accuracy = 0.094
# ------------------------------
# train data stats for 15 step
# Loss = 2.328
# Accuracy = 0.141
# ------------------------------
# train data stats for 16 step
# Loss = 2.293
# Accuracy = 0.125
# ------------------------------
# train data stats for 17 step
# Loss = 2.294
# Accuracy = 0.141
# ------------------------------
# train data stats for 18 step
# Loss = 2.379
# Accuracy = 0.016
# ------------------------------
# train data stats for 19 step
# Loss = 2.310
# Accuracy = 0.062
# ------------------------------
# train data stats for 20 step
# Loss = 2.330
# Accuracy = 0.094
# ------------------------------
# train data stats for 21 step
# Loss = 2.315
# Accuracy = 0.078
# ------------------------------
# train data stats for 22 step
# Loss = 2.301
# Accuracy = 0.156
# ------------------------------
# train data stats for 23 step
# Loss = 2.315
# Accuracy = 0.078
# ------------------------------
# train data stats for 24 step
# Loss = 2.316
# Accuracy = 0.062
# ------------------------------
# train data stats for 25 step
# Loss = 2.307
# Accuracy = 0.062
# ------------------------------
# train data stats for 26 step
# Loss = 2.307
# Accuracy = 0.062
# ------------------------------
# train data stats for 27 step
# Loss = 2.281
# Accuracy = 0.094
# ------------------------------
# train data stats for 28 step
# Loss = 2.314
# Accuracy = 0.047
# ------------------------------
# train data stats for 29 step
# Loss = 2.297
# Accuracy = 0.125
# ------------------------------
# train data stats for 30 step
# Loss = 2.317
# Accuracy = 0.047
# ------------------------------
# train data stats for 31 step
# Loss = 2.316
# Accuracy = 0.141
# ------------------------------
# train data stats for 32 step
# Loss = 2.297
# Accuracy = 0.094
# ------------------------------
# train data stats for 33 step
# Loss = 2.295
# Accuracy = 0.125
# ------------------------------
# train data stats for 34 step
# Loss = 2.300
# Accuracy = 0.125
# ------------------------------
# train data stats for 35 step
# Loss = 2.309
# Accuracy = 0.094
# ------------------------------
# train data stats for 36 step
# Loss = 2.327
# Accuracy = 0.031
# ------------------------------
# train data stats for 37 step
# Loss = 2.308
# Accuracy = 0.062
# ------------------------------
# train data stats for 38 step
# Loss = 2.285
# Accuracy = 0.125
# ------------------------------
# train data stats for 39 step
# Loss = 2.299
# Accuracy = 0.078
# ------------------------------
# train data stats for 40 step
# Loss = 2.296
# Accuracy = 0.109
# ------------------------------
# train data stats for 41 step
# Loss = 2.307
# Accuracy = 0.062
# ------------------------------
# train data stats for 42 step
# Loss = 2.316
# Accuracy = 0.031
# ------------------------------
# train data stats for 43 step
# Loss = 2.301
# Accuracy = 0.078
# ------------------------------
# train data stats for 44 step
# Loss = 2.318
# Accuracy = 0.062
# ------------------------------
# train data stats for 45 step
# Loss = 2.282
# Accuracy = 0.141
# ------------------------------
# train data stats for 46 step
# Loss = 2.304
# Accuracy = 0.047
# ------------------------------
# train data stats for 47 step
# Loss = 2.298
# Accuracy = 0.141
# ------------------------------
# train data stats for 48 step
# Loss = 2.305
# Accuracy = 0.109
# ------------------------------
# train data stats for 49 step
# Loss = 2.294
# Accuracy = 0.125
# ------------------------------
# train data stats for 50 step
# Loss = 2.304
# Accuracy = 0.047
# ------------------------------
# train data stats for 51 step
# Loss = 2.297
# Accuracy = 0.109
# ------------------------------
# train data stats for 52 step
# Loss = 2.278
# Accuracy = 0.125
# ------------------------------
# train data stats for 53 step
# Loss = 2.298
# Accuracy = 0.109
# ------------------------------
# train data stats for 54 step
# Loss = 2.295
# Accuracy = 0.078
# ------------------------------
# train data stats for 55 step
# Loss = 2.297
# Accuracy = 0.047
# ------------------------------
# train data stats for 56 step
# Loss = 2.314
# Accuracy = 0.047
# ------------------------------
# train data stats for 57 step
# Loss = 2.298
# Accuracy = 0.109
# ------------------------------
# train data stats for 58 step
# Loss = 2.299
# Accuracy = 0.109
# ------------------------------
# train data stats for 59 step
# Loss = 2.322
# Accuracy = 0.078
# ------------------------------
# train data stats for 60 step
# Loss = 2.293
# Accuracy = 0.094
# ------------------------------
# train data stats for 61 step
# Loss = 2.313
# Accuracy = 0.141
# ------------------------------
# train data stats for 62 step
# Loss = 2.296
# Accuracy = 0.078
# ------------------------------
# train data stats for 63 step
# Loss = 2.287
# Accuracy = 0.109
# ------------------------------
# train data stats for 64 step
# Loss = 2.309
# Accuracy = 0.062
# ------------------------------
# train data stats for 65 step
# Loss = 2.289
# Accuracy = 0.109
# ------------------------------
# train data stats for 66 step
# Loss = 2.284
# Accuracy = 0.141
# ------------------------------
# train data stats for 67 step
# Loss = 2.284
# Accuracy = 0.203
# ------------------------------
# train data stats for 68 step
# Loss = 2.285
# Accuracy = 0.156
# ------------------------------
# train data stats for 69 step
# Loss = 2.298
# Accuracy = 0.047
# ------------------------------
# train data stats for 70 step
# Loss = 2.293
# Accuracy = 0.141
# ------------------------------
# train data stats for 71 step
# Loss = 2.279
# Accuracy = 0.203
# ------------------------------
# train data stats for 72 step
# Loss = 2.286
# Accuracy = 0.156
# ------------------------------
# train data stats for 73 step
# Loss = 2.320
# Accuracy = 0.141
# ------------------------------
# train data stats for 74 step
# Loss = 2.289
# Accuracy = 0.141
# ------------------------------
# train data stats for 75 step
# Loss = 2.301
# Accuracy = 0.047
# ------------------------------
# train data stats for 76 step
# Loss = 2.277
# Accuracy = 0.250
# ------------------------------
# train data stats for 77 step
# Loss = 2.308
# Accuracy = 0.125
# ------------------------------
# train data stats for 78 step
# Loss = 2.281
# Accuracy = 0.156
# ------------------------------
# train data stats for 79 step
# Loss = 2.284
# Accuracy = 0.109
# ------------------------------
# train data stats for 80 step
# Loss = 2.305
# Accuracy = 0.031
# ------------------------------
# train data stats for 81 step
# Loss = 2.294
# Accuracy = 0.141
# ------------------------------
# train data stats for 82 step
# Loss = 2.291
# Accuracy = 0.109
# ------------------------------
# train data stats for 83 step
# Loss = 2.294
# Accuracy = 0.125
# ------------------------------
# train data stats for 84 step
# Loss = 2.288
# Accuracy = 0.047
# ------------------------------
# train data stats for 85 step
# Loss = 2.289
# Accuracy = 0.172
# ------------------------------
# train data stats for 86 step
# Loss = 2.297
# Accuracy = 0.172
# ------------------------------
# train data stats for 87 step
# Loss = 2.282
# Accuracy = 0.125
# ------------------------------
# train data stats for 88 step
# Loss = 2.298
# Accuracy = 0.062
# ------------------------------
# train data stats for 89 step
# Loss = 2.274
# Accuracy = 0.172
# ------------------------------
# train data stats for 90 step
# Loss = 2.286
# Accuracy = 0.094
# ------------------------------
# train data stats for 91 step
# Loss = 2.290
# Accuracy = 0.109
# ------------------------------
# train data stats for 92 step
# Loss = 2.286
# Accuracy = 0.172
# ------------------------------
# train data stats for 93 step
# Loss = 2.294
# Accuracy = 0.125
# ------------------------------
# train data stats for 94 step
# Loss = 2.272
# Accuracy = 0.141
# ------------------------------
# train data stats for 95 step
# Loss = 2.299
# Accuracy = 0.094
# ------------------------------
# train data stats for 96 step
# Loss = 2.283
# Accuracy = 0.094
# ------------------------------
# train data stats for 97 step
# Loss = 2.258
# Accuracy = 0.172
# ------------------------------
# train data stats for 98 step
# Loss = 2.280
# Accuracy = 0.125
# ------------------------------
# train data stats for 99 step
# Loss = 2.290
# Accuracy = 0.109
# ------------------------------
# train data stats for 100 step
# Loss = 2.269
# Accuracy = 0.188
# ------------------------------
# train data stats for 101 step
# Loss = 2.302
# Accuracy = 0.109
# ------------------------------
# train data stats for 102 step
# Loss = 2.279
# Accuracy = 0.094
# ------------------------------
# train data stats for 103 step
# Loss = 2.290
# Accuracy = 0.094
# ------------------------------
# train data stats for 104 step
# Loss = 2.281
# Accuracy = 0.109
# ------------------------------
# train data stats for 105 step
# Loss = 2.302
# Accuracy = 0.094
# ------------------------------
# train data stats for 106 step
# Loss = 2.312
# Accuracy = 0.125
# ------------------------------
# train data stats for 107 step
# Loss = 2.280
# Accuracy = 0.234
# ------------------------------
# train data stats for 108 step
# Loss = 2.306
# Accuracy = 0.094
# ------------------------------
# train data stats for 109 step
# Loss = 2.305
# Accuracy = 0.078
# ------------------------------
# train data stats for 110 step
# Loss = 2.304
# Accuracy = 0.156
# ------------------------------
# train data stats for 111 step
# Loss = 2.288
# Accuracy = 0.188
# ------------------------------
# train data stats for 112 step
# Loss = 2.278
# Accuracy = 0.172
# ------------------------------
# train data stats for 113 step
# Loss = 2.270
# Accuracy = 0.109
# ------------------------------
# train data stats for 114 step
# Loss = 2.296
# Accuracy = 0.125
# ------------------------------
# train data stats for 115 step
# Loss = 2.288
# Accuracy = 0.156
# ------------------------------
# train data stats for 116 step
# Loss = 2.275
# Accuracy = 0.156
# ------------------------------
# train data stats for 117 step
# Loss = 2.298
# Accuracy = 0.094
# ------------------------------
# train data stats for 118 step
# Loss = 2.273
# Accuracy = 0.172
# ------------------------------
# train data stats for 119 step
# Loss = 2.284
# Accuracy = 0.172
# ------------------------------
# train data stats for 120 step
# Loss = 2.282
# Accuracy = 0.156
# ------------------------------
# train data stats for 121 step
# Loss = 2.303
# Accuracy = 0.141
# ------------------------------
# train data stats for 122 step
# Loss = 2.281
# Accuracy = 0.234
# ------------------------------
# train data stats for 123 step
# Loss = 2.289
# Accuracy = 0.109
# ------------------------------
# train data stats for 124 step
# Loss = 2.285
# Accuracy = 0.141
# ------------------------------
# train data stats for 125 step
# Loss = 2.288
# Accuracy = 0.156
# ------------------------------
# train data stats for 126 step
# Loss = 2.291
# Accuracy = 0.094
# ------------------------------
# train data stats for 127 step
# Loss = 2.282
# Accuracy = 0.141
# ------------------------------
# train data stats for 128 step
# Loss = 2.278
# Accuracy = 0.172
# ------------------------------
# train data stats for 129 step
# Loss = 2.282
# Accuracy = 0.141
# ------------------------------
# train data stats for 130 step
# Loss = 2.270
# Accuracy = 0.234
# ------------------------------
# train data stats for 131 step
# Loss = 2.300
# Accuracy = 0.047
# ------------------------------
# train data stats for 132 step
# Loss = 2.271
# Accuracy = 0.156
# ------------------------------
# train data stats for 133 step
# Loss = 2.308
# Accuracy = 0.109
# ------------------------------
# train data stats for 134 step
# Loss = 2.278
# Accuracy = 0.156
# ------------------------------
# train data stats for 135 step
# Loss = 2.280
# Accuracy = 0.125
# ------------------------------
# train data stats for 136 step
# Loss = 2.274
# Accuracy = 0.188
# ------------------------------
# train data stats for 137 step
# Loss = 2.293
# Accuracy = 0.078
# ------------------------------
# train data stats for 138 step
# Loss = 2.284
# Accuracy = 0.125
# ------------------------------
# train data stats for 139 step
# Loss = 2.295
# Accuracy = 0.094
# ------------------------------
# train data stats for 140 step
# Loss = 2.286
# Accuracy = 0.188
# ------------------------------
# train data stats for 141 step
# Loss = 2.283
# Accuracy = 0.141
# ------------------------------
# train data stats for 142 step
# Loss = 2.278
# Accuracy = 0.156
# ------------------------------
# train data stats for 143 step
# Loss = 2.290
# Accuracy = 0.125
# ------------------------------
# train data stats for 144 step
# Loss = 2.265
# Accuracy = 0.219
# ------------------------------
# train data stats for 145 step
# Loss = 2.289
# Accuracy = 0.188
# ------------------------------
# train data stats for 146 step
# Loss = 2.289
# Accuracy = 0.094
# ------------------------------
# train data stats for 147 step
# Loss = 2.274
# Accuracy = 0.156
# ------------------------------
# train data stats for 148 step
# Loss = 2.289
# Accuracy = 0.078
# ------------------------------
# train data stats for 149 step
# Loss = 2.287
# Accuracy = 0.094
# ------------------------------
# train data stats for 150 step
# Loss = 2.281
# Accuracy = 0.156
# ------------------------------
# train data stats for 151 step
# Loss = 2.269
# Accuracy = 0.141
# ------------------------------
# train data stats for 152 step
# Loss = 2.281
# Accuracy = 0.172
# ------------------------------
# train data stats for 153 step
# Loss = 2.299
# Accuracy = 0.094
# ------------------------------
# train data stats for 154 step
# Loss = 2.288
# Accuracy = 0.078
# ------------------------------
# train data stats for 155 step
# Loss = 2.280
# Accuracy = 0.172
# ------------------------------
# train data stats for 156 step
# Loss = 2.274
# Accuracy = 0.156
# ------------------------------
# train data stats for 157 step
# Loss = 2.270
# Accuracy = 0.141
# ------------------------------
# train data stats for 158 step
# Loss = 2.284
# Accuracy = 0.094
# ------------------------------
# train data stats for 159 step
# Loss = 2.284
# Accuracy = 0.094
# ------------------------------
# train data stats for 160 step
# Loss = 2.271
# Accuracy = 0.125
# ------------------------------
# train data stats for 161 step
# Loss = 2.286
# Accuracy = 0.156
# ------------------------------
# train data stats for 162 step
# Loss = 2.291
# Accuracy = 0.094
# ------------------------------
# train data stats for 163 step
# Loss = 2.297
# Accuracy = 0.141
# ------------------------------
# train data stats for 164 step
# Loss = 2.276
# Accuracy = 0.219
# ------------------------------
# train data stats for 165 step
# Loss = 2.269
# Accuracy = 0.203
# ------------------------------
# train data stats for 166 step
# Loss = 2.270
# Accuracy = 0.172
# ------------------------------
# train data stats for 167 step
# Loss = 2.274
# Accuracy = 0.172
# ------------------------------
# train data stats for 168 step
# Loss = 2.259
# Accuracy = 0.172
# ------------------------------
# train data stats for 169 step
# Loss = 2.278
# Accuracy = 0.188
# ------------------------------
# train data stats for 170 step
# Loss = 2.259
# Accuracy = 0.219
# ------------------------------
# train data stats for 171 step
# Loss = 2.260
# Accuracy = 0.203
# ------------------------------
# train data stats for 172 step
# Loss = 2.288
# Accuracy = 0.094
# ------------------------------
# train data stats for 173 step
# Loss = 2.289
# Accuracy = 0.141
# ------------------------------
# train data stats for 174 step
# Loss = 2.272
# Accuracy = 0.172
# ------------------------------
# train data stats for 175 step
# Loss = 2.281
# Accuracy = 0.188
# ------------------------------
# train data stats for 176 step
# Loss = 2.270
# Accuracy = 0.172
# ------------------------------
# train data stats for 177 step
# Loss = 2.279
# Accuracy = 0.078
# ------------------------------
# train data stats for 178 step
# Loss = 2.257
# Accuracy = 0.188
# ------------------------------
# train data stats for 179 step
# Loss = 2.265
# Accuracy = 0.203
# ------------------------------
# train data stats for 180 step
# Loss = 2.290
# Accuracy = 0.125
# ------------------------------
# train data stats for 181 step
# Loss = 2.268
# Accuracy = 0.188
# ------------------------------
# train data stats for 182 step
# Loss = 2.278
# Accuracy = 0.172
# ------------------------------
# train data stats for 183 step
# Loss = 2.269
# Accuracy = 0.172
# ------------------------------
# train data stats for 184 step
# Loss = 2.295
# Accuracy = 0.062
# ------------------------------
# train data stats for 185 step
# Loss = 2.273
# Accuracy = 0.188
# ------------------------------
# train data stats for 186 step
# Loss = 2.290
# Accuracy = 0.141
# ------------------------------
# train data stats for 187 step
# Loss = 2.275
# Accuracy = 0.172
# ------------------------------
# train data stats for 188 step
# Loss = 2.272
# Accuracy = 0.219
# ------------------------------
# train data stats for 189 step
# Loss = 2.286
# Accuracy = 0.141
# ------------------------------
# train data stats for 190 step
# Loss = 2.264
# Accuracy = 0.156
# ------------------------------
# train data stats for 191 step
# Loss = 2.266
# Accuracy = 0.188
# ------------------------------
# train data stats for 192 step
# Loss = 2.259
# Accuracy = 0.156
# ------------------------------
# train data stats for 193 step
# Loss = 2.274
# Accuracy = 0.109
# ------------------------------
# train data stats for 194 step
# Loss = 2.259
# Accuracy = 0.203
# ------------------------------
# train data stats for 195 step
# Loss = 2.316
# Accuracy = 0.062
# ------------------------------
# train data stats for 196 step
# Loss = 2.269
# Accuracy = 0.188
# ------------------------------
# train data stats for 197 step
# Loss = 2.290
# Accuracy = 0.078
# ------------------------------
# train data stats for 198 step
# Loss = 2.276
# Accuracy = 0.141
# ------------------------------
# train data stats for 199 step
# Loss = 2.273
# Accuracy = 0.141
# ------------------------------
# train data stats for 200 step
# Loss = 2.273
# Accuracy = 0.125
# ------------------------------
# train data stats for 201 step
# Loss = 2.268
# Accuracy = 0.156
# ------------------------------
# train data stats for 202 step
# Loss = 2.256
# Accuracy = 0.266
# ------------------------------
# train data stats for 203 step
# Loss = 2.276
# Accuracy = 0.203
# ------------------------------
# train data stats for 204 step
# Loss = 2.277
# Accuracy = 0.156
# ------------------------------
# train data stats for 205 step
# Loss = 2.274
# Accuracy = 0.172
# ------------------------------
# train data stats for 206 step
# Loss = 2.271
# Accuracy = 0.125
# ------------------------------
# train data stats for 207 step
# Loss = 2.255
# Accuracy = 0.203
# ------------------------------
# train data stats for 208 step
# Loss = 2.268
# Accuracy = 0.219
# ------------------------------
# train data stats for 209 step
# Loss = 2.261
# Accuracy = 0.203
# ------------------------------
# train data stats for 210 step
# Loss = 2.267
# Accuracy = 0.156
# ------------------------------
# train data stats for 211 step
# Loss = 2.263
# Accuracy = 0.172
# ------------------------------
# train data stats for 212 step
# Loss = 2.280
# Accuracy = 0.109
# ------------------------------
# train data stats for 213 step
# Loss = 2.264
# Accuracy = 0.203
# ------------------------------
# train data stats for 214 step
# Loss = 2.279
# Accuracy = 0.078
# ------------------------------
# train data stats for 215 step
# Loss = 2.285
# Accuracy = 0.109
# ------------------------------
# train data stats for 216 step
# Loss = 2.264
# Accuracy = 0.266
# ------------------------------
# train data stats for 217 step
# Loss = 2.282
# Accuracy = 0.219
# ------------------------------
# train data stats for 218 step
# Loss = 2.271
# Accuracy = 0.125
# ------------------------------
# train data stats for 219 step
# Loss = 2.277
# Accuracy = 0.078
# ------------------------------
# train data stats for 220 step
# Loss = 2.264
# Accuracy = 0.172
# ------------------------------
# train data stats for 221 step
# Loss = 2.283
# Accuracy = 0.125
# ------------------------------
# train data stats for 222 step
# Loss = 2.268
# Accuracy = 0.156
# ------------------------------
# train data stats for 223 step
# Loss = 2.281
# Accuracy = 0.141
# ------------------------------
# train data stats for 224 step
# Loss = 2.265
# Accuracy = 0.156
# ------------------------------
# train data stats for 225 step
# Loss = 2.289
# Accuracy = 0.062
# ------------------------------
# train data stats for 226 step
# Loss = 2.289
# Accuracy = 0.141
# ------------------------------
# train data stats for 227 step
# Loss = 2.268
# Accuracy = 0.219
# ------------------------------
# train data stats for 228 step
# Loss = 2.264
# Accuracy = 0.219
# ------------------------------
# train data stats for 229 step
# Loss = 2.251
# Accuracy = 0.203
# ------------------------------
# train data stats for 230 step
# Loss = 2.264
# Accuracy = 0.188
# ------------------------------
# train data stats for 231 step
# Loss = 2.276
# Accuracy = 0.125
# ------------------------------
# train data stats for 232 step
# Loss = 2.255
# Accuracy = 0.203
# ------------------------------
# train data stats for 233 step
# Loss = 2.255
# Accuracy = 0.234
# ------------------------------
# train data stats for 234 step
# Loss = 2.267
# Accuracy = 0.172
# ------------------------------
# train data stats for 235 step
# Loss = 2.276
# Accuracy = 0.172
# ------------------------------
# train data stats for 236 step
# Loss = 2.283
# Accuracy = 0.141
# ------------------------------
# train data stats for 237 step
# Loss = 2.277
# Accuracy = 0.094
# ------------------------------
# train data stats for 238 step
# Loss = 2.276
# Accuracy = 0.125
# ------------------------------
# train data stats for 239 step
# Loss = 2.271
# Accuracy = 0.141
# ------------------------------
# train data stats for 240 step
# Loss = 2.281
# Accuracy = 0.109
# ------------------------------
# train data stats for 241 step
# Loss = 2.261
# Accuracy = 0.156
# ------------------------------
# train data stats for 242 step
# Loss = 2.277
# Accuracy = 0.219
# ------------------------------
# train data stats for 243 step
# Loss = 2.262
# Accuracy = 0.250
# ------------------------------
# train data stats for 244 step
# Loss = 2.260
# Accuracy = 0.156
# ------------------------------
# train data stats for 245 step
# Loss = 2.263
# Accuracy = 0.234
# ------------------------------
# train data stats for 246 step
# Loss = 2.268
# Accuracy = 0.109
# ------------------------------
# train data stats for 247 step
# Loss = 2.272
# Accuracy = 0.156
# ------------------------------
# train data stats for 248 step
# Loss = 2.268
# Accuracy = 0.125
# ------------------------------
# train data stats for 249 step
# Loss = 2.259
# Accuracy = 0.172
# ------------------------------
# train data stats for 250 step
# Loss = 2.258
# Accuracy = 0.125
# ------------------------------
# train data stats for 251 step
# Loss = 2.281
# Accuracy = 0.141
# ------------------------------
# train data stats for 252 step
# Loss = 2.265
# Accuracy = 0.156
# ------------------------------
# train data stats for 253 step
# Loss = 2.255
# Accuracy = 0.203
# ------------------------------
# train data stats for 254 step
# Loss = 2.262
# Accuracy = 0.188
# ------------------------------
# train data stats for 255 step
# Loss = 2.280
# Accuracy = 0.172
# ------------------------------
# train data stats for 256 step
# Loss = 2.286
# Accuracy = 0.094
# ------------------------------
# train data stats for 257 step
# Loss = 2.277
# Accuracy = 0.156
# ------------------------------
# train data stats for 258 step
# Loss = 2.279
# Accuracy = 0.047
# ------------------------------
# train data stats for 259 step
# Loss = 2.280
# Accuracy = 0.203
# ------------------------------
# train data stats for 260 step
# Loss = 2.293
# Accuracy = 0.094
# ------------------------------
# train data stats for 261 step
# Loss = 2.276
# Accuracy = 0.266
# ------------------------------
# train data stats for 262 step
# Loss = 2.250
# Accuracy = 0.250
# ------------------------------
# train data stats for 263 step
# Loss = 2.274
# Accuracy = 0.109
# ------------------------------
# train data stats for 264 step
# Loss = 2.268
# Accuracy = 0.219
# ------------------------------
# train data stats for 265 step
# Loss = 2.266
# Accuracy = 0.172
# ------------------------------
# train data stats for 266 step
# Loss = 2.270
# Accuracy = 0.109
# ------------------------------
# train data stats for 267 step
# Loss = 2.262
# Accuracy = 0.141
# ------------------------------
# train data stats for 268 step
# Loss = 2.287
# Accuracy = 0.062
# ------------------------------
# train data stats for 269 step
# Loss = 2.252
# Accuracy = 0.203
# ------------------------------
# train data stats for 270 step
# Loss = 2.264
# Accuracy = 0.250
# ------------------------------
# train data stats for 271 step
# Loss = 2.277
# Accuracy = 0.062
# ------------------------------
# train data stats for 272 step
# Loss = 2.234
# Accuracy = 0.266
# ------------------------------
# train data stats for 273 step
# Loss = 2.254
# Accuracy = 0.188
# ------------------------------
# train data stats for 274 step
# Loss = 2.262
# Accuracy = 0.250
# ------------------------------
# train data stats for 275 step
# Loss = 2.271
# Accuracy = 0.109
# ------------------------------
# train data stats for 276 step
# Loss = 2.267
# Accuracy = 0.156
# ------------------------------
# train data stats for 277 step
# Loss = 2.267
# Accuracy = 0.203
# ------------------------------
# train data stats for 278 step
# Loss = 2.276
# Accuracy = 0.188
# ------------------------------
# train data stats for 279 step
# Loss = 2.258
# Accuracy = 0.141
# ------------------------------
# train data stats for 280 step
# Loss = 2.277
# Accuracy = 0.172
# ------------------------------
# train data stats for 281 step
# Loss = 2.252
# Accuracy = 0.188
# ------------------------------
# train data stats for 282 step
# Loss = 2.255
# Accuracy = 0.125
# ------------------------------
# train data stats for 283 step
# Loss = 2.252
# Accuracy = 0.172
# ------------------------------
# train data stats for 284 step
# Loss = 2.245
# Accuracy = 0.188
# ------------------------------
# train data stats for 285 step
# Loss = 2.266
# Accuracy = 0.156
# ------------------------------
# train data stats for 286 step
# Loss = 2.251
# Accuracy = 0.266
# ------------------------------
# train data stats for 287 step
# Loss = 2.269
# Accuracy = 0.219
# ------------------------------
# train data stats for 288 step
# Loss = 2.247
# Accuracy = 0.250
# ------------------------------
# train data stats for 289 step
# Loss = 2.258
# Accuracy = 0.172
# ------------------------------
# train data stats for 290 step
# Loss = 2.262
# Accuracy = 0.156
# ------------------------------
# train data stats for 291 step
# Loss = 2.271
# Accuracy = 0.156
# ------------------------------
# train data stats for 292 step
# Loss = 2.262
# Accuracy = 0.219
# ------------------------------
# train data stats for 293 step
# Loss = 2.256
# Accuracy = 0.188
# ------------------------------
# train data stats for 294 step
# Loss = 2.279
# Accuracy = 0.188
# ------------------------------
# train data stats for 295 step
# Loss = 2.262
# Accuracy = 0.141
# ------------------------------
# train data stats for 296 step
# Loss = 2.268
# Accuracy = 0.172
# ------------------------------
# train data stats for 297 step
# Loss = 2.274
# Accuracy = 0.141
# ------------------------------
# train data stats for 298 step
# Loss = 2.260
# Accuracy = 0.172
# ------------------------------
# train data stats for 299 step
# Loss = 2.273
# Accuracy = 0.156
# ------------------------------
# train data stats for 300 step
# Loss = 2.251
# Accuracy = 0.203
# ------------------------------
# train data stats for 301 step
# Loss = 2.256
# Accuracy = 0.156
# ------------------------------
# train data stats for 302 step
# Loss = 2.283
# Accuracy = 0.078
# ------------------------------
# train data stats for 303 step
# Loss = 2.256
# Accuracy = 0.188
# ------------------------------
# train data stats for 304 step
# Loss = 2.241
# Accuracy = 0.266
# ------------------------------
# train data stats for 305 step
# Loss = 2.284
# Accuracy = 0.172
# ------------------------------
# train data stats for 306 step
# Loss = 2.265
# Accuracy = 0.141
# ------------------------------
# train data stats for 307 step
# Loss = 2.264
# Accuracy = 0.172
# ------------------------------
# train data stats for 308 step
# Loss = 2.237
# Accuracy = 0.250
# ------------------------------
# train data stats for 309 step
# Loss = 2.280
# Accuracy = 0.078
# ------------------------------
# train data stats for 310 step
# Loss = 2.268
# Accuracy = 0.172
# ------------------------------
# train data stats for 311 step
# Loss = 2.262
# Accuracy = 0.156
# ------------------------------
# train data stats for 312 step
# Loss = 2.269
# Accuracy = 0.141
# ------------------------------
# train data stats for 313 step
# Loss = 2.262
# Accuracy = 0.141
# ------------------------------
# train data stats for 314 step
# Loss = 2.260
# Accuracy = 0.156
# ------------------------------
# train data stats for 315 step
# Loss = 2.244
# Accuracy = 0.109
# ------------------------------
# train data stats for 316 step
# Loss = 2.260
# Accuracy = 0.172
# ------------------------------
# train data stats for 317 step
# Loss = 2.275
# Accuracy = 0.141
# ------------------------------
# train data stats for 318 step
# Loss = 2.282
# Accuracy = 0.141
# ------------------------------
# train data stats for 319 step
# Loss = 2.262
# Accuracy = 0.203
# ------------------------------
# train data stats for 320 step
# Loss = 2.261
# Accuracy = 0.172
# ------------------------------
# train data stats for 321 step
# Loss = 2.241
# Accuracy = 0.219
# ------------------------------
# train data stats for 322 step
# Loss = 2.261
# Accuracy = 0.219
# ------------------------------
# train data stats for 323 step
# Loss = 2.263
# Accuracy = 0.172
# ------------------------------
# train data stats for 324 step
# Loss = 2.254
# Accuracy = 0.172
# ------------------------------
# train data stats for 325 step
# Loss = 2.259
# Accuracy = 0.203
# ------------------------------
# train data stats for 326 step
# Loss = 2.248
# Accuracy = 0.156
# ------------------------------
# train data stats for 327 step
# Loss = 2.261
# Accuracy = 0.141
# ------------------------------
# train data stats for 328 step
# Loss = 2.262
# Accuracy = 0.203
# ------------------------------
# train data stats for 329 step
# Loss = 2.260
# Accuracy = 0.156
# ------------------------------
# train data stats for 330 step
# Loss = 2.247
# Accuracy = 0.125
# ------------------------------
# train data stats for 331 step
# Loss = 2.268
# Accuracy = 0.172
# ------------------------------
# train data stats for 332 step
# Loss = 2.252
# Accuracy = 0.156
# ------------------------------
# train data stats for 333 step
# Loss = 2.251
# Accuracy = 0.234
# ------------------------------
# train data stats for 334 step
# Loss = 2.247
# Accuracy = 0.156
# ------------------------------
# train data stats for 335 step
# Loss = 2.268
# Accuracy = 0.125
# ------------------------------
# train data stats for 336 step
# Loss = 2.260
# Accuracy = 0.125
# ------------------------------
# train data stats for 337 step
# Loss = 2.283
# Accuracy = 0.125
# ------------------------------
# train data stats for 338 step
# Loss = 2.237
# Accuracy = 0.312
# ------------------------------
# train data stats for 339 step
# Loss = 2.230
# Accuracy = 0.281
# ------------------------------
# train data stats for 340 step
# Loss = 2.265
# Accuracy = 0.109
# ------------------------------
# train data stats for 341 step
# Loss = 2.235
# Accuracy = 0.172
# ------------------------------
# train data stats for 342 step
# Loss = 2.267
# Accuracy = 0.172
# ------------------------------
# train data stats for 343 step
# Loss = 2.252
# Accuracy = 0.312
# ------------------------------
# train data stats for 344 step
# Loss = 2.240
# Accuracy = 0.297
# ------------------------------
# train data stats for 345 step
# Loss = 2.264
# Accuracy = 0.125
# ------------------------------
# train data stats for 346 step
# Loss = 2.220
# Accuracy = 0.250
# ------------------------------
# train data stats for 347 step
# Loss = 2.249
# Accuracy = 0.188
# ------------------------------
# train data stats for 348 step
# Loss = 2.250
# Accuracy = 0.141
# ------------------------------
# train data stats for 349 step
# Loss = 2.240
# Accuracy = 0.297
# ------------------------------
# train data stats for 350 step
# Loss = 2.260
# Accuracy = 0.125
# ------------------------------
# train data stats for 351 step
# Loss = 2.247
# Accuracy = 0.219
# ------------------------------
# train data stats for 352 step
# Loss = 2.255
# Accuracy = 0.172
# ------------------------------
# train data stats for 353 step
# Loss = 2.266
# Accuracy = 0.156
# ------------------------------
# train data stats for 354 step
# Loss = 2.251
# Accuracy = 0.188
# ------------------------------
# train data stats for 355 step
# Loss = 2.265
# Accuracy = 0.172
# ------------------------------
# train data stats for 356 step
# Loss = 2.252
# Accuracy = 0.188
# ------------------------------
# train data stats for 357 step
# Loss = 2.249
# Accuracy = 0.250
# ------------------------------
# train data stats for 358 step
# Loss = 2.260
# Accuracy = 0.141
# ------------------------------
# train data stats for 359 step
# Loss = 2.236
# Accuracy = 0.188
# ------------------------------
# train data stats for 360 step
# Loss = 2.252
# Accuracy = 0.250
# ------------------------------
# train data stats for 361 step
# Loss = 2.270
# Accuracy = 0.172
# ------------------------------
# train data stats for 362 step
# Loss = 2.236
# Accuracy = 0.234
# ------------------------------
# train data stats for 363 step
# Loss = 2.240
# Accuracy = 0.203
# ------------------------------
# train data stats for 364 step
# Loss = 2.273
# Accuracy = 0.188
# ------------------------------
# train data stats for 365 step
# Loss = 2.245
# Accuracy = 0.234
# ------------------------------
# train data stats for 366 step
# Loss = 2.262
# Accuracy = 0.125
# ------------------------------
# train data stats for 367 step
# Loss = 2.250
# Accuracy = 0.125
# ------------------------------
# train data stats for 368 step
# Loss = 2.247
# Accuracy = 0.234
# ------------------------------
# train data stats for 369 step
# Loss = 2.248
# Accuracy = 0.203
# ------------------------------
# train data stats for 370 step
# Loss = 2.257
# Accuracy = 0.172
# ------------------------------
# train data stats for 371 step
# Loss = 2.251
# Accuracy = 0.219
# ------------------------------
# train data stats for 372 step
# Loss = 2.273
# Accuracy = 0.203
# ------------------------------
# train data stats for 373 step
# Loss = 2.209
# Accuracy = 0.234
# ------------------------------
# train data stats for 374 step
# Loss = 2.266
# Accuracy = 0.172
# ------------------------------
# train data stats for 375 step
# Loss = 2.240
# Accuracy = 0.219
# ------------------------------
# train data stats for 376 step
# Loss = 2.253
# Accuracy = 0.156
# ------------------------------
# train data stats for 377 step
# Loss = 2.262
# Accuracy = 0.141
# ------------------------------
# train data stats for 378 step
# Loss = 2.243
# Accuracy = 0.234
# ------------------------------
# train data stats for 379 step
# Loss = 2.260
# Accuracy = 0.250
# ------------------------------
# train data stats for 380 step
# Loss = 2.251
# Accuracy = 0.250
# ------------------------------
# train data stats for 381 step
# Loss = 2.264
# Accuracy = 0.141
# ------------------------------
# train data stats for 382 step
# Loss = 2.250
# Accuracy = 0.219
# ------------------------------
# train data stats for 383 step
# Loss = 2.238
# Accuracy = 0.250
# ------------------------------
# train data stats for 384 step
# Loss = 2.234
# Accuracy = 0.219
# ------------------------------
# train data stats for 385 step
# Loss = 2.297
# Accuracy = 0.078
# ------------------------------
# train data stats for 386 step
# Loss = 2.238
# Accuracy = 0.297
# ------------------------------
# train data stats for 387 step
# Loss = 2.268
# Accuracy = 0.172
# ------------------------------
# train data stats for 388 step
# Loss = 2.256
# Accuracy = 0.297
# ------------------------------
# train data stats for 389 step
# Loss = 2.257
# Accuracy = 0.203
# ------------------------------
# train data stats for 390 step
# Loss = 2.243
# Accuracy = 0.250
# ------------------------------
# train data stats for 391 step
# Loss = 2.252
# Accuracy = 0.172
# ------------------------------
# train data stats for 392 step
# Loss = 2.256
# Accuracy = 0.125
# ------------------------------
# train data stats for 393 step
# Loss = 2.256
# Accuracy = 0.188
# ------------------------------
# train data stats for 394 step
# Loss = 2.237
# Accuracy = 0.219
# ------------------------------
# train data stats for 395 step
# Loss = 2.258
# Accuracy = 0.281
# ------------------------------
# train data stats for 396 step
# Loss = 2.270
# Accuracy = 0.188
# ------------------------------
# train data stats for 397 step
# Loss = 2.264
# Accuracy = 0.156
# ------------------------------
# train data stats for 398 step
# Loss = 2.231
# Accuracy = 0.172
# ------------------------------
# train data stats for 399 step
# Loss = 2.263
# Accuracy = 0.188
# ------------------------------
# train data stats for 400 step
# Loss = 2.237
# Accuracy = 0.266
# ------------------------------
# train data stats for 401 step
# Loss = 2.271
# Accuracy = 0.156
# ------------------------------
# train data stats for 402 step
# Loss = 2.263
# Accuracy = 0.094
# ------------------------------
# train data stats for 403 step
# Loss = 2.251
# Accuracy = 0.141
# ------------------------------
# train data stats for 404 step
# Loss = 2.231
# Accuracy = 0.266
# ------------------------------
# train data stats for 405 step
# Loss = 2.237
# Accuracy = 0.250
# ------------------------------
# train data stats for 406 step
# Loss = 2.255
# Accuracy = 0.219
# ------------------------------
# train data stats for 407 step
# Loss = 2.242
# Accuracy = 0.219
# ------------------------------
# train data stats for 408 step
# Loss = 2.272
# Accuracy = 0.172
# ------------------------------
# train data stats for 409 step
# Loss = 2.236
# Accuracy = 0.266
# ------------------------------
# train data stats for 410 step
# Loss = 2.254
# Accuracy = 0.156
# ------------------------------
# train data stats for 411 step
# Loss = 2.239
# Accuracy = 0.250
# ------------------------------
# train data stats for 412 step
# Loss = 2.257
# Accuracy = 0.234
# ------------------------------
# train data stats for 413 step
# Loss = 2.249
# Accuracy = 0.250
# ------------------------------
# train data stats for 414 step
# Loss = 2.243
# Accuracy = 0.156
# ------------------------------
# train data stats for 415 step
# Loss = 2.247
# Accuracy = 0.219
# ------------------------------
# train data stats for 416 step
# Loss = 2.265
# Accuracy = 0.156
# ------------------------------
# train data stats for 417 step
# Loss = 2.250
# Accuracy = 0.125
# ------------------------------
# train data stats for 418 step
# Loss = 2.237
# Accuracy = 0.250
# ------------------------------
# train data stats for 419 step
# Loss = 2.285
# Accuracy = 0.156
# ------------------------------
# train data stats for 420 step
# Loss = 2.238
# Accuracy = 0.219
# ------------------------------
# train data stats for 421 step
# Loss = 2.244
# Accuracy = 0.172
# ------------------------------
# train data stats for 422 step
# Loss = 2.245
# Accuracy = 0.203
# ------------------------------
# train data stats for 423 step
# Loss = 2.254
# Accuracy = 0.203
# ------------------------------
# train data stats for 424 step
# Loss = 2.246
# Accuracy = 0.203
# ------------------------------
# train data stats for 425 step
# Loss = 2.245
# Accuracy = 0.219
# ------------------------------
# train data stats for 426 step
# Loss = 2.264
# Accuracy = 0.219
# ------------------------------
# train data stats for 427 step
# Loss = 2.249
# Accuracy = 0.172
# ------------------------------
# train data stats for 428 step
# Loss = 2.270
# Accuracy = 0.125
# ------------------------------
# train data stats for 429 step
# Loss = 2.227
# Accuracy = 0.219
# ------------------------------
# train data stats for 430 step
# Loss = 2.230
# Accuracy = 0.234
# ------------------------------
# train data stats for 431 step
# Loss = 2.272
# Accuracy = 0.172
# ------------------------------
# train data stats for 432 step
# Loss = 2.225
# Accuracy = 0.188
# ------------------------------
# train data stats for 433 step
# Loss = 2.241
# Accuracy = 0.219
# ------------------------------
# train data stats for 434 step
# Loss = 2.228
# Accuracy = 0.172
# ------------------------------
# train data stats for 435 step
# Loss = 2.240
# Accuracy = 0.266
# ------------------------------
# train data stats for 436 step
# Loss = 2.229
# Accuracy = 0.172
# ------------------------------
# train data stats for 437 step
# Loss = 2.245
# Accuracy = 0.172
# ------------------------------
# train data stats for 438 step
# Loss = 2.239
# Accuracy = 0.266
# ------------------------------
# train data stats for 439 step
# Loss = 2.218
# Accuracy = 0.234
# ------------------------------
# train data stats for 440 step
# Loss = 2.257
# Accuracy = 0.109
# ------------------------------
# train data stats for 441 step
# Loss = 2.249
# Accuracy = 0.141
# ------------------------------
# train data stats for 442 step
# Loss = 2.241
# Accuracy = 0.203
# ------------------------------
# train data stats for 443 step
# Loss = 2.220
# Accuracy = 0.141
# ------------------------------
# train data stats for 444 step
# Loss = 2.243
# Accuracy = 0.219
# ------------------------------
# train data stats for 445 step
# Loss = 2.260
# Accuracy = 0.266
# ------------------------------
# train data stats for 446 step
# Loss = 2.249
# Accuracy = 0.188
# ------------------------------
# train data stats for 447 step
# Loss = 2.254
# Accuracy = 0.172
# ------------------------------
# train data stats for 448 step
# Loss = 2.239
# Accuracy = 0.125
# ------------------------------
# train data stats for 449 step
# Loss = 2.207
# Accuracy = 0.250
# ------------------------------
# train data stats for 450 step
# Loss = 2.258
# Accuracy = 0.219
# ------------------------------
# train data stats for 451 step
# Loss = 2.219
# Accuracy = 0.234
# ------------------------------
# train data stats for 452 step
# Loss = 2.255
# Accuracy = 0.141
# ------------------------------
# train data stats for 453 step
# Loss = 2.245
# Accuracy = 0.188
# ------------------------------
# train data stats for 454 step
# Loss = 2.248
# Accuracy = 0.203
# ------------------------------
# train data stats for 455 step
# Loss = 2.240
# Accuracy = 0.297
# ------------------------------
# train data stats for 456 step
# Loss = 2.256
# Accuracy = 0.172
# ------------------------------
# train data stats for 457 step
# Loss = 2.232
# Accuracy = 0.250
# ------------------------------
# train data stats for 458 step
# Loss = 2.210
# Accuracy = 0.266
# ------------------------------
# train data stats for 459 step
# Loss = 2.257
# Accuracy = 0.156
# ------------------------------
# train data stats for 460 step
# Loss = 2.252
# Accuracy = 0.266
# ------------------------------
# train data stats for 461 step
# Loss = 2.210
# Accuracy = 0.188
# ------------------------------
# train data stats for 462 step
# Loss = 2.247
# Accuracy = 0.109
# ------------------------------
# train data stats for 463 step
# Loss = 2.252
# Accuracy = 0.188
# ------------------------------
# train data stats for 464 step
# Loss = 2.230
# Accuracy = 0.250
# ------------------------------
# train data stats for 465 step
# Loss = 2.218
# Accuracy = 0.328
# ------------------------------
# train data stats for 466 step
# Loss = 2.220
# Accuracy = 0.297
# ------------------------------
# train data stats for 467 step
# Loss = 2.258
# Accuracy = 0.203
# ------------------------------
# train data stats for 468 step
# Loss = 2.237
# Accuracy = 0.172
# ------------------------------
# train data stats for 469 step
# Loss = 2.229
# Accuracy = 0.219
# ------------------------------
# train data stats for 470 step
# Loss = 2.204
# Accuracy = 0.250
# ------------------------------
# train data stats for 471 step
# Loss = 2.254
# Accuracy = 0.203
# ------------------------------
# train data stats for 472 step
# Loss = 2.256
# Accuracy = 0.219
# ------------------------------
# train data stats for 473 step
# Loss = 2.224
# Accuracy = 0.156
# ------------------------------
# train data stats for 474 step
# Loss = 2.229
# Accuracy = 0.219
# ------------------------------
# train data stats for 475 step
# Loss = 2.233
# Accuracy = 0.156
# ------------------------------
# train data stats for 476 step
# Loss = 2.231
# Accuracy = 0.234
# ------------------------------
# train data stats for 477 step
# Loss = 2.251
# Accuracy = 0.109
# ------------------------------
# train data stats for 478 step
# Loss = 2.260
# Accuracy = 0.156
# ------------------------------
# train data stats for 479 step
# Loss = 2.257
# Accuracy = 0.141
# ------------------------------
# train data stats for 480 step
# Loss = 2.233
# Accuracy = 0.172
# ------------------------------
# train data stats for 481 step
# Loss = 2.238
# Accuracy = 0.172
# ------------------------------
# train data stats for 482 step
# Loss = 2.258
# Accuracy = 0.109
# ------------------------------
# train data stats for 483 step
# Loss = 2.232
# Accuracy = 0.188
# ------------------------------
# train data stats for 484 step
# Loss = 2.219
# Accuracy = 0.203
# ------------------------------
# train data stats for 485 step
# Loss = 2.249
# Accuracy = 0.156
# ------------------------------
# train data stats for 486 step
# Loss = 2.255
# Accuracy = 0.250
# ------------------------------
# train data stats for 487 step
# Loss = 2.239
# Accuracy = 0.266
# ------------------------------
# train data stats for 488 step
# Loss = 2.263
# Accuracy = 0.125
# ------------------------------
# train data stats for 489 step
# Loss = 2.247
# Accuracy = 0.156
# ------------------------------
# train data stats for 490 step
# Loss = 2.215
# Accuracy = 0.266
# ------------------------------
# train data stats for 491 step
# Loss = 2.235
# Accuracy = 0.219
# ------------------------------
# train data stats for 492 step
# Loss = 2.195
# Accuracy = 0.344
# ------------------------------
# train data stats for 493 step
# Loss = 2.244
# Accuracy = 0.281
# ------------------------------
# train data stats for 494 step
# Loss = 2.227
# Accuracy = 0.219
# ------------------------------
# train data stats for 495 step
# Loss = 2.234
# Accuracy = 0.141
# ------------------------------
# train data stats for 496 step
# Loss = 2.262
# Accuracy = 0.203
# ------------------------------
# train data stats for 497 step
# Loss = 2.252
# Accuracy = 0.156
# ------------------------------
# train data stats for 498 step
# Loss = 2.207
# Accuracy = 0.188
# ------------------------------
# train data stats for 499 step
# Loss = 2.226
# Accuracy = 0.203
# ------------------------------
# train data stats for 500 step
# Loss = 2.262
# Accuracy = 0.203
# ------------------------------
# train data stats for 501 step
# Loss = 2.269
# Accuracy = 0.203
# ------------------------------
# train data stats for 502 step
# Loss = 2.249
# Accuracy = 0.203
# ------------------------------
# train data stats for 503 step
# Loss = 2.216
# Accuracy = 0.281
# ------------------------------
# train data stats for 504 step
# Loss = 2.269
# Accuracy = 0.172
# ------------------------------
# train data stats for 505 step
# Loss = 2.246
# Accuracy = 0.172
# ------------------------------
# train data stats for 506 step
# Loss = 2.266
# Accuracy = 0.125
# ------------------------------
# train data stats for 507 step
# Loss = 2.238
# Accuracy = 0.234
# ------------------------------
# train data stats for 508 step
# Loss = 2.228
# Accuracy = 0.250
# ------------------------------
# train data stats for 509 step
# Loss = 2.211
# Accuracy = 0.203
# ------------------------------
# train data stats for 510 step
# Loss = 2.241
# Accuracy = 0.328
# ------------------------------
# train data stats for 511 step
# Loss = 2.242
# Accuracy = 0.219
# ------------------------------
# train data stats for 512 step
# Loss = 2.249
# Accuracy = 0.141
# ------------------------------
# train data stats for 513 step
# Loss = 2.278
# Accuracy = 0.078
# ------------------------------
# train data stats for 514 step
# Loss = 2.213
# Accuracy = 0.203
# ------------------------------
# train data stats for 515 step
# Loss = 2.253
# Accuracy = 0.172
# ------------------------------
# train data stats for 516 step
# Loss = 2.248
# Accuracy = 0.172
# ------------------------------
# train data stats for 517 step
# Loss = 2.254
# Accuracy = 0.188
# ------------------------------
# train data stats for 518 step
# Loss = 2.212
# Accuracy = 0.188
# ------------------------------
# train data stats for 519 step
# Loss = 2.252
# Accuracy = 0.219
# ------------------------------
# train data stats for 520 step
# Loss = 2.233
# Accuracy = 0.234
# ------------------------------
# train data stats for 521 step
# Loss = 2.201
# Accuracy = 0.219
# ------------------------------
# train data stats for 522 step
# Loss = 2.278
# Accuracy = 0.094
# ------------------------------
# train data stats for 523 step
# Loss = 2.227
# Accuracy = 0.219
# ------------------------------
# train data stats for 524 step
# Loss = 2.207
# Accuracy = 0.188
# ------------------------------
# train data stats for 525 step
# Loss = 2.212
# Accuracy = 0.219
# ------------------------------
# train data stats for 526 step
# Loss = 2.236
# Accuracy = 0.141
# ------------------------------
# train data stats for 527 step
# Loss = 2.219
# Accuracy = 0.188
# ------------------------------
# train data stats for 528 step
# Loss = 2.251
# Accuracy = 0.141
# ...
# train data stats for 760 step
# Loss = 1.867
# Accuracy = 0.328
# ------------------------------
# train data stats for 761 step
# Loss = 1.940
# Accuracy = 0.375
# ------------------------------
# train data stats for 762 step
# Loss = 1.949
# Accuracy = 0.328
# ------------------------------
# train data stats for 763 step
# Loss = 2.091
# Accuracy = 0.281
# ------------------------------
# train data stats for 764 step
# Loss = 1.942
# Accuracy = 0.359
# ------------------------------
# train data stats for 765 step
# Loss = 1.981
# Accuracy = 0.312
# ------------------------------
# train data stats for 766 step
# Loss = 1.907
# Accuracy = 0.391
# ------------------------------
# train data stats for 767 step
# Loss = 2.131
# Accuracy = 0.234
# ------------------------------
# train data stats for 768 step
# Loss = 2.100
# Accuracy = 0.250
# ------------------------------
# train data stats for 769 step
# Loss = 1.910
# Accuracy = 0.391
# ------------------------------
# train data stats for 770 step
# Loss = 1.944
# Accuracy = 0.375
# ------------------------------
# train data stats for 771 step
# Loss = 1.988
# Accuracy = 0.266
# ------------------------------
# train data stats for 772 step
# Loss = 2.070
# Accuracy = 0.234
# ------------------------------
# train data stats for 773 step
# Loss = 1.901
# Accuracy = 0.391
# ------------------------------
# train data stats for 774 step
# Loss = 1.957
# Accuracy = 0.375
# ------------------------------
# train data stats for 775 step
# Loss = 1.900
# Accuracy = 0.391
# ------------------------------
# train data stats for 776 step
# Loss = 1.949
# Accuracy = 0.266
# ------------------------------
# train data stats for 777 step
# Loss = 2.087
# Accuracy = 0.219
# ------------------------------
# train data stats for 778 step
# Loss = 1.819
# Accuracy = 0.453
# ------------------------------
# train data stats for 779 step
# Loss = 1.901
# Accuracy = 0.281
# ------------------------------
# train data stats for 780 step
# Loss = 1.942
# Accuracy = 0.344
# ------------------------------
# valid data stats for 0 step
# Loss = 1.975
# Accuracy = 0.328
# ------------------------------
# valid data stats for 1 step
# Loss = 1.997
# Accuracy = 0.250
# ------------------------------
# valid data stats for 2 step
# Loss = 1.873
# Accuracy = 0.375
# ------------------------------
# valid data stats for 3 step
# Loss = 2.005
# Accuracy = 0.250
# ------------------------------
# valid data stats for 4 step
# Loss = 1.985
# Accuracy = 0.297
# ------------------------------
# valid data stats for 5 step
# Loss = 1.941
# Accuracy = 0.406
# ------------------------------
# valid data stats for 6 step
# Loss = 1.933
# Accuracy = 0.391
# ------------------------------
# valid data stats for 7 step
# Loss = 2.015
# Accuracy = 0.297
# ------------------------------
# valid data stats for 8 step
# Loss = 1.988
# Accuracy = 0.328
# ------------------------------
# valid data stats for 9 step
# Loss = 1.958
# Accuracy = 0.359
# ------------------------------
# valid data stats for 10 step
# Loss = 2.079
# Accuracy = 0.266
# ------------------------------
# valid data stats for 11 step
# Loss = 1.990
# Accuracy = 0.375
# ------------------------------
# valid data stats for 12 step
# Loss = 2.031
# Accuracy = 0.375
# ------------------------------
# valid data stats for 13 step
# Loss = 2.033
# Accuracy = 0.344
# ------------------------------
# valid data stats for 14 step
# Loss = 1.994
# Accuracy = 0.281
# ------------------------------
# valid data stats for 15 step
# Loss = 1.939
# Accuracy = 0.344
# ------------------------------
# valid data stats for 16 step
# Loss = 1.894
# Accuracy = 0.391
# ------------------------------
# valid data stats for 17 step
# Loss = 1.948
# Accuracy = 0.297
# ------------------------------
# valid data stats for 18 step
# Loss = 1.962
# Accuracy = 0.281
# ------------------------------
# valid data stats for 19 step
# Loss = 2.048
# Accuracy = 0.250
# ------------------------------
# valid data stats for 20 step
# Loss = 1.989
# Accuracy = 0.281
# ------------------------------
# valid data stats for 21 step
# Loss = 1.968
# Accuracy = 0.328
# ------------------------------
# valid data stats for 22 step
# Loss = 1.973
# Accuracy = 0.250
# ------------------------------
# valid data stats for 23 step
# Loss = 1.920
# Accuracy = 0.281
# ------------------------------
# valid data stats for 24 step
# Loss = 1.971
# Accuracy = 0.297
# ------------------------------
# valid data stats for 25 step
# Loss = 1.907
# Accuracy = 0.344
# ------------------------------
# valid data stats for 26 step
# Loss = 1.982
# Accuracy = 0.344
# ------------------------------
# valid data stats for 27 step
# Loss = 1.958
# Accuracy = 0.297
# ------------------------------
# valid data stats for 28 step
# Loss = 1.907
# Accuracy = 0.422
# ------------------------------
# valid data stats for 29 step
# Loss = 1.970
# Accuracy = 0.297
# ------------------------------
# valid data stats for 30 step
# Loss = 1.918
# Accuracy = 0.312
# ------------------------------
# valid data stats for 31 step
# Loss = 2.043
# Accuracy = 0.281
# ------------------------------
# valid data stats for 32 step
# Loss = 1.998
# Accuracy = 0.312
# ------------------------------
# valid data stats for 33 step
# Loss = 2.010
# Accuracy = 0.203
# ------------------------------
# valid data stats for 34 step
# Loss = 1.943
# Accuracy = 0.312
# ------------------------------
# valid data stats for 35 step
# Loss = 1.962
# Accuracy = 0.391
# ------------------------------
# valid data stats for 36 step
# Loss = 1.897
# Accuracy = 0.359
# ------------------------------
# valid data stats for 37 step
# Loss = 1.978
# Accuracy = 0.297
# ------------------------------
# valid data stats for 38 step
# Loss = 2.028
# Accuracy = 0.281
# ------------------------------
# valid data stats for 39 step
# Loss = 1.908
# Accuracy = 0.344
# ------------------------------
# valid data stats for 40 step
# Loss = 1.974
# Accuracy = 0.281
# ------------------------------
# valid data stats for 41 step
# Loss = 2.128
# Accuracy = 0.297
# ------------------------------
# valid data stats for 42 step
# Loss = 2.040
# Accuracy = 0.266
# ------------------------------
# valid data stats for 43 step
# Loss = 1.938
# Accuracy = 0.344
# ------------------------------
# valid data stats for 44 step
# Loss = 2.020
# Accuracy = 0.250
# ------------------------------
# valid data stats for 45 step
# Loss = 1.969
# Accuracy = 0.234
# ------------------------------
# valid data stats for 46 step
# Loss = 1.938
# Accuracy = 0.344
# ------------------------------
# valid data stats for 47 step
# Loss = 2.052
# Accuracy = 0.297
# ------------------------------
# valid data stats for 48 step
# Loss = 1.924
# Accuracy = 0.453
# ------------------------------
# valid data stats for 49 step
# Loss = 1.819
# Accuracy = 0.391
# ------------------------------
# valid data stats for 50 step
# Loss = 1.930
# Accuracy = 0.391
# ------------------------------
# valid data stats for 51 step
# Loss = 1.937
# Accuracy = 0.375
# ------------------------------
# valid data stats for 52 step
# Loss = 1.963
# Accuracy = 0.375
# ------------------------------
# valid data stats for 53 step
# Loss = 1.912
# Accuracy = 0.359
# ------------------------------
# valid data stats for 54 step
# Loss = 1.986
# Accuracy = 0.297
# ------------------------------
# valid data stats for 55 step
# Loss = 1.844
# Accuracy = 0.375
# ------------------------------
# valid data stats for 56 step
# Loss = 2.001
# Accuracy = 0.312
# ------------------------------
# valid data stats for 57 step
# Loss = 1.849
# Accuracy = 0.422
# ------------------------------
# valid data stats for 58 step
# Loss = 1.987
# Accuracy = 0.359
# ------------------------------
# valid data stats for 59 step
# Loss = 1.995
# Accuracy = 0.219
# ------------------------------
# valid data stats for 60 step
# Loss = 2.090
# Accuracy = 0.281
# ------------------------------
# valid data stats for 61 step
# Loss = 2.006
# Accuracy = 0.203
# ------------------------------
# valid data stats for 62 step
# Loss = 1.934
# Accuracy = 0.422
# ------------------------------
# valid data stats for 63 step
# Loss = 1.954
# Accuracy = 0.266
# ------------------------------
# valid data stats for 64 step
# Loss = 1.992
# Accuracy = 0.391
# ------------------------------
# valid data stats for 65 step
# Loss = 2.029
# Accuracy = 0.328
# ------------------------------
# valid data stats for 66 step
# Loss = 1.951
# Accuracy = 0.234
# ------------------------------
# valid data stats for 67 step
# Loss = 1.834
# Accuracy = 0.375
# ------------------------------
# valid data stats for 68 step
# Loss = 1.986
# Accuracy = 0.328
# ------------------------------
# valid data stats for 69 step
# Loss = 2.068
# Accuracy = 0.203
# ------------------------------
# valid data stats for 70 step
# Loss = 1.974
# Accuracy = 0.312
# ------------------------------
# valid data stats for 71 step
# Loss = 1.984
# Accuracy = 0.297
# ------------------------------
# valid data stats for 72 step
# Loss = 1.988
# Accuracy = 0.297
# ------------------------------
# valid data stats for 73 step
# Loss = 1.950
# Accuracy = 0.344
# ------------------------------
# valid data stats for 74 step
# Loss = 1.904
# Accuracy = 0.312
# ------------------------------
# valid data stats for 75 step
# Loss = 1.877
# Accuracy = 0.328
# ------------------------------
# valid data stats for 76 step
# Loss = 2.004
# Accuracy = 0.234
# ------------------------------
# valid data stats for 77 step
# Loss = 2.088
# Accuracy = 0.312
# ------------------------------
# valid data stats for 78 step
# Loss = 1.910
# Accuracy = 0.359
# ------------------------------
# valid data stats for 79 step
# Loss = 1.893
# Accuracy = 0.406
# ------------------------------
# valid data stats for 80 step
# Loss = 2.091
# Accuracy = 0.281
# ------------------------------
# valid data stats for 81 step
# Loss = 1.979
# Accuracy = 0.312
# ------------------------------
# valid data stats for 82 step
# Loss = 1.907
# Accuracy = 0.375
# ------------------------------
# valid data stats for 83 step
# Loss = 2.086
# Accuracy = 0.266
# ------------------------------
# valid data stats for 84 step
# Loss = 1.951
# Accuracy = 0.281
# ------------------------------
# valid data stats for 85 step
# Loss = 1.951
# Accuracy = 0.297
# ------------------------------
# valid data stats for 86 step
# Loss = 2.048
# Accuracy = 0.203
# ------------------------------
# valid data stats for 87 step
# Loss = 1.929
# Accuracy = 0.297
# ------------------------------
# valid data stats for 88 step
# Loss = 2.082
# Accuracy = 0.219
# ------------------------------
# valid data stats for 89 step
# Loss = 2.050
# Accuracy = 0.312
# ------------------------------
# valid data stats for 90 step
# Loss = 1.950
# Accuracy = 0.422
# ------------------------------
# valid data stats for 91 step
# Loss = 1.984
# Accuracy = 0.297
# ------------------------------
# valid data stats for 92 step
# Loss = 2.001
# Accuracy = 0.219
# ------------------------------
# valid data stats for 93 step
# Loss = 2.005
# Accuracy = 0.391
# ------------------------------
# valid data stats for 94 step
# Loss = 1.922
# Accuracy = 0.297
# ------------------------------
# valid data stats for 95 step
# Loss = 2.034
# Accuracy = 0.281
# ------------------------------
# valid data stats for 96 step
# Loss = 2.010
# Accuracy = 0.266
# ------------------------------
# valid data stats for 97 step
# Loss = 1.970
# Accuracy = 0.375
# ------------------------------
# valid data stats for 98 step
# Loss = 2.107
# Accuracy = 0.266
# ------------------------------
# valid data stats for 99 step
# Loss = 1.854
# Accuracy = 0.328
# ------------------------------
# valid data stats for 100 step
# Loss = 1.942
# Accuracy = 0.344
# ------------------------------
# valid data stats for 101 step
# Loss = 1.975
# Accuracy = 0.281
# ------------------------------
# valid data stats for 102 step
# Loss = 2.079
# Accuracy = 0.234
# ------------------------------
# valid data stats for 103 step
# Loss = 1.986
# Accuracy = 0.297
# ------------------------------
# valid data stats for 104 step
# Loss = 2.046
# Accuracy = 0.312
# ------------------------------
# valid data stats for 105 step
# Loss = 1.963
# Accuracy = 0.344
# ------------------------------
# valid data stats for 106 step
# Loss = 1.992
# Accuracy = 0.422
# ------------------------------
# valid data stats for 107 step
# Loss = 1.978
# Accuracy = 0.406
# ------------------------------
# valid data stats for 108 step
# Loss = 1.945
# Accuracy = 0.312
# ------------------------------
# valid data stats for 109 step
# Loss = 2.068
# Accuracy = 0.281
# ------------------------------
# valid data stats for 110 step
# Loss = 2.015
# Accuracy = 0.281
# ------------------------------
# valid data stats for 111 step
# Loss = 1.975
# Accuracy = 0.250
# ------------------------------
# valid data stats for 112 step
# Loss = 1.966
# Accuracy = 0.234
# ------------------------------
# valid data stats for 113 step
# Loss = 1.990
# Accuracy = 0.312
# ------------------------------
# valid data stats for 114 step
# Loss = 1.973
# Accuracy = 0.328
# ------------------------------
# valid data stats for 115 step
# Loss = 2.057
# Accuracy = 0.281
# ------------------------------
# valid data stats for 116 step
# Loss = 2.017
# Accuracy = 0.266
# ------------------------------
# valid data stats for 117 step
# Loss = 1.984
# Accuracy = 0.344
# ------------------------------
# valid data stats for 118 step
# Loss = 1.849
# Accuracy = 0.406
# ------------------------------
# valid data stats for 119 step
# Loss = 2.053
# Accuracy = 0.359
# ------------------------------
# valid data stats for 120 step
# Loss = 1.906
# Accuracy = 0.406
# ------------------------------
# valid data stats for 121 step
# Loss = 1.801
# Accuracy = 0.422
# ------------------------------
# valid data stats for 122 step
# Loss = 2.038
# Accuracy = 0.297
# ------------------------------
# valid data stats for 123 step
# Loss = 2.035
# Accuracy = 0.281
# ------------------------------
# valid data stats for 124 step
# Loss = 1.991
# Accuracy = 0.281
# ------------------------------
# valid data stats for 125 step
# Loss = 1.974
# Accuracy = 0.312
# ------------------------------
# valid data stats for 126 step
# Loss = 2.020
# Accuracy = 0.266
# ------------------------------
# valid data stats for 127 step
# Loss = 2.050
# Accuracy = 0.234
# ------------------------------
# valid data stats for 128 step
# Loss = 1.931
# Accuracy = 0.219
# ------------------------------
# valid data stats for 129 step
# Loss = 1.953
# Accuracy = 0.391
# ------------------------------
# valid data stats for 130 step
# Loss = 1.964
# Accuracy = 0.328
# ------------------------------
# valid data stats for 131 step
# Loss = 1.951
# Accuracy = 0.312
# ------------------------------
# valid data stats for 132 step
# Loss = 1.886
# Accuracy = 0.375
# ------------------------------
# valid data stats for 133 step
# Loss = 1.942
# Accuracy = 0.328
# ------------------------------
# valid data stats for 134 step
# Loss = 2.056
# Accuracy = 0.266
# ------------------------------
# valid data stats for 135 step
# Loss = 1.861
# Accuracy = 0.391
# ------------------------------
# valid data stats for 136 step
# Loss = 1.972
# Accuracy = 0.281
# ------------------------------
# valid data stats for 137 step
# Loss = 2.005
# Accuracy = 0.328
# ------------------------------
# valid data stats for 138 step
# Loss = 2.005
# Accuracy = 0.281
# ------------------------------
# valid data stats for 139 step
# Loss = 1.884
# Accuracy = 0.344
# ------------------------------
# valid data stats for 140 step
# Loss = 2.028
# Accuracy = 0.281
# ------------------------------
# valid data stats for 141 step
# Loss = 2.006
# Accuracy = 0.297
# ------------------------------
# valid data stats for 142 step
# Loss = 1.916
# Accuracy = 0.375
# ------------------------------
# valid data stats for 143 step
# Loss = 2.082
# Accuracy = 0.281
# ------------------------------
# valid data stats for 144 step
# Loss = 1.947
# Accuracy = 0.297
# ------------------------------
# valid data stats for 145 step
# Loss = 1.919
# Accuracy = 0.328
# ------------------------------
# valid data stats for 146 step
# Loss = 1.963
# Accuracy = 0.266
# ------------------------------
# valid data stats for 147 step
# Loss = 1.999
# Accuracy = 0.281
# ------------------------------
# valid data stats for 148 step
# Loss = 2.026
# Accuracy = 0.281
# ------------------------------
# valid data stats for 149 step
# Loss = 2.031
# Accuracy = 0.281
# ------------------------------
# valid data stats for 150 step
# Loss = 1.921
# Accuracy = 0.312
# ------------------------------
# valid data stats for 151 step
# Loss = 1.988
# Accuracy = 0.344
# ------------------------------
# valid data stats for 152 step
# Loss = 1.891
# Accuracy = 0.344
# ------------------------------
# valid data stats for 153 step
# Loss = 1.962
# Accuracy = 0.359
# ------------------------------
# valid data stats for 154 step
# Loss = 2.031
# Accuracy = 0.297
# ------------------------------
# valid data stats for 155 step
# Loss = 1.920
# Accuracy = 0.312
# ------------------------------

# %%
tlp_stats.best_results()
# Out:
# Epoch 09      loss       acc
# train     1.993300  0.315181
# valid     1.984473  0.324319

# %%
tlp_stats.plot_by_epoch()

# %%
tlp_stats.plot_by_batch(block_len=10)

# %% [markdown]
# ## Modul: ReLU nelinearita

# %% [markdown]
# Sigmoid se z důvodu jeho nevýhodných vlastností pro trénování (především "zabíjení" gradientu při zpětné propagaci) dnes s výjimkou rekurentních sítí již téměř nepoužívá. V současnosti je jednou z nejpopulárnějších nelinearit Recitifed Linear Unit (ReLU), která nuluje vstupy se zápornou hodnotou. Má podobu:
#
# **Dopředný průchod**
# $$h = \max(0, s)$$
#
# **Zpětný průchod**
# $$\frac{\partial L}{\partial s} = \frac{\partial L}{\partial h} \boldsymbol{1}(s \ge 0)$$
#
# **Poznámka ke gradient checku**
#
# Jelikoz ReLU není diferencovatelná, nemusí si numerický a analytický gradient vždy odpovídat. Chyba vznikne, pokud je ve vstupu $s$ nějaká hodnota blíže nule než je krok $\Delta_s$ pro numerickou diferenci. Např. centrální diference v bodě 0.001 s krokem 0.01 je
# $$\frac{ReLU(0.001 + 0.01) - ReLU(0.001 - 0.01)}{2\cdot 0.01} = \frac{0.011 - 0}{0.02} = 0.55$$
# zatímco analyticky je derivace v bodě $0.001$ rovna přesně $1$. Je tedy možné, že se občas objeví velká rel. odchylka gradientů, mnohem častěji pro malé hodnoty vstupu $s$. Napravit to lze např. menším krokem $\Delta_s$ numerické diference, který by měl být řádově menší než vstup $s$.

# %%
class ReLU(Layer):
    
    def __init__(self):
        super().__init__()
    
    def forward(self, score):
        hidden = score.clone().detach()
        hidden[hidden<0] = 0
        self._cache = {
            'score': hidden
        }

        return hidden
    
    def backward(self, dhidden):
        score = self._cache['score']
        score[score<0] = 0.
        dh = dhidden.clone().detach()
        dh[score==0] = 0.
        dscore = dh
        dparams = {}
        
        #################################################################
        
        return dscore, dparams

# %%
# overime na male davce
score = torch.randn(10, 3)

# "simulace" prichoziho gradientu, ktery ma vrstva dale propagovat
dhidden = torch.randn(10, 3)

# instance vrstvy
relu_layer = ReLU()

# krok vypoctu numerickeho gradientu nastavime manualne
neural.check_gradients(relu_layer, score, dhidden, h=0.001);
# Out:
# dinput1 error:  0.328021356055484

# %% [markdown]
# # Konfigurovatelný model vícevrstvého perceptronu (bonusová úloha)

# %% [markdown]
# Jako bonus navrhněte třídu `FeedForwardNet`, která bude moci mít libovolnou konfiguraci vrstev. Uvažujte pouze jednodušší variantu, kdy vstupem do každé následující vrstvy je výstup vrstvy předchozí. Třída by měla do konstruktoru přijímat pole s vrstvami tak, jak půjdou za sebou v dopředném průchodu. Příklad použití lze vidět v buňce s gradient checkem.
#
# Plně propojené neuronové sítě hlubší než několik málo vrstev dlouhou dobu nedosahovaly výkonnosti jiných metod strojového učení (např. rozhodovací stromy či boosting). Jednou z příčin byla nevhodná inicializace parametrů, díky které aktivace neuronů ve vyšších vrstvách mají nevhodné statistické rozložení (viz přednášku) a zpětná propagace gradientu je pak velice obtížná. Pokud síť projde gradient checkem, ale přesto se z dat neučí, hlavním podezřelým bude nejspíše právě inicializace. Pro úspěšné trénování je proto dobré implementovat `xavier` inicializaci ve vrstvě `Linear`.

# %%
class FeedForwardNet(Layer):
    def __init__(self, layers):
        super().__init__()
        
        self.layers = layers
        self.params = {}
        #################################################################
        # ZDE DOPLNIT
        
        # dynamicky z predanych vrstev naplnit slovnik parametru,
        # analogicky k postupu z TwoLayerPerceptron

        for i in range(len(self.layers)):
            if "weights" in self.layers[i].params.keys():
                self.params[f'weights{i}'] = self.layers[i].params['weights']
            if "bias" in self.layers[i].params.keys():
                self.params[f'bias{i}'] = self.layers[i].params['bias']
        #################################################################
    
    def forward(self, inputs):
        
        #################################################################
        # ZDE DOPLNIT
        
        # dopredny pruchod je jednoduchy, jen se jednotlive vrstvy zavolaji
        # tak, jak jdou za sebou
            
        #################################################################

        for i in range(len(self.layers)):
            if "weights" in self.layers[i].params.keys():
                self.layers[i].params['weights'] = self.params[f'weights{i}']
            if "bias" in self.layers[i].params.keys():
                self.layers[i].params['bias'] = self.params[f'bias{i}']

        last_input = inputs
        for i in range(len(self.layers)):
            last_input = self.layers[i].forward(last_input)
        return last_input
    
    def backward(self, dscore):
        
        #################################################################
        # ZDE DOPLNIT
        
        # vrstvy se musi projit v obracenem poradi a postupne volat jejich
        # zpetne pruchody, dokud nedojdeme az zpet na vstup
        
        #################################################################
        dl_i, dl = dscore, None
        i = len(self.layers)
        dparams = {}
        for i in range(len(self.layers))[::-1]:
            dl_i, dl = self.layers[i].backward(dl_i)
            if "weights" in dl.keys():
                dparams[f'weights{i}'] = dl['weights']
            if "bias" in dl.keys():
                dparams[f'bias{i}'] = dl['bias']
            i -= 1
        
        return dl_i, dparams

# %%
inputs = torch.randn(10, 5)
dscore = torch.randn(10, 3)
relu_layer = FeedForwardNet([
    LinearLayer(5, 3),
    Sigmoid(),
    LinearLayer(3, 3),
    Sigmoid(),
    LinearLayer(3, 3)
])
neural.check_gradients(relu_layer, inputs, dscore);
# Out:
# dinput1 error:  5.036973350685283e-09
# dweights0 error:  7.870875252841485e-10
# dbias0 error:  1.8251067630243338e-09
# dweights2 error:  7.771235651524551e-10
# dbias2 error:  2.4273302159878384e-11
# dweights4 error:  2.3340895479879885e-11
# dbias4 error:  5.002780077333458e-13

# %%
mlp_model = FeedForwardNet([
    Linear(X_train.shape[1], 1028),
    ReLU(),
    Linear(1028, 512),
    ReLU(),
    Linear(512, 512),
    ReLU(),
    Linear(512, 128),
    ReLU(),
    Linear(128, 128),
    ReLU(),
    Linear(128, torch.unique(y_train).shape[0])
    # libovolne lze pokracovat
])

sce = SoftmaxCrossEntropy()

train_loader = BatchLoader(X_train, y_train, 256, 'train', shuffle=True)
valid_loader = BatchLoader(X_valid, y_valid, 256, 'valid', shuffle=True)

optimizer = StochasticGradientDescent(mlp_model.params, learning_rate=0.001, weight_decay_l2=0.01)

mlp_stats = Stats()

# %%
for ep in range(2):
    mlp_stats.new_epoch()
    neural.train(mlp_model, sce, train_loader, optimizer, mlp_stats)
    neural.validate(mlp_model, sce, valid_loader, mlp_stats)
# Out:
# epochs [{'train': {'loss': [2.3054294278752607, 2.3109052532401475, 2.3064031279204213, 2.300797748038778, 2.3059641166027065, 2.302610234405785, 2.3042868861610595, 2.3090977834326987, 2.307916689515336, 2.3041446664652945, 2.300635748458471, 2.313936396622914, 2.3065199050734777, 2.3110716527642143, 2.306238372660458, 2.3059668954455943, 2.3061885106988815, 2.306337628000395, 2.3048647614514386, 2.3081513110562435, 2.305735679493026, 2.310364071347732, 2.3058027659550024, 2.3070115786909735, 2.3069043895068666, 2.299764728160649, 2.3086184032173227, 2.3055454152819617, 2.304415937965514, 2.3016469478227304, 2.3029302453922686, 2.305216210591785, 2.3035071241922918, 2.306248622631087, 2.3071956672959013, 2.299653534834077, 2.308499317797026, 2.3063900140570883, 2.3026471673444084, 2.306247792205873, 2.3006673063752605, 2.2985494048622486, 2.3016545423691053, 2.2960994179993555, 2.303201770529469, 2.2969214419944537, 2.294878808261691, 2.3072730823538112, 2.2999453555529517, 2.303143760680861, 2.2984559725240077, 2.2956455370512625, 2.3083021478418377, 2.3059290946622726, 2.304152959298958, 2.305738138377645, 2.2963358303200687, 2.3014967009873315, 2.3009049694010644, 2.2974790928805304, 2.301201650091941, 2.3030092062106178, 2.301009377175135, 2.3067493414431874, 2.3048927476087586, 2.303388879640536, 2.302417095059117, 2.2999452601593258, 2.3009075752690586, 2.3004824065715535, 2.306766771146947, 2.30336180245071, 2.3001357746066438, 2.299437747201127, 2.2944375386082445, 2.3039334730148435, 2.3088657404110617, 2.2988691587093206, 2.3020177778020656, 2.298458974624136, 2.3020965905057986, 2.2937490451556233, 2.2957694661211585, 2.2990915413616633, 2.3026418843246432, 2.3059750922134703, 2.29936166488526, 2.3009938236937257, 2.298314803858193, 2.3018497651200565, 2.3047241038053805, 2.2987917280157744, 2.3006117106608106, 2.2942046123338633, 2.303176987845239, 2.2993464601434703, 2.307392929846247, 2.296202322847151, 2.299342858145163, 2.297083878115815, 2.3000280792764416, 2.304273802637013, 2.3045382993346175, 2.3084450679115447, 2.3015597510060855, 2.2955878967581373, 2.2952647370228423, 2.2961430865310017, 2.3032165263597317, 2.2946685321541356, 2.301208567734511, 2.3009751343680067, 2.3014959181124337, 2.3049114384173537, 2.302232361268601, 2.2989944450047797, 2.2982211429985044, 2.2976683634166872, 2.2965211512127723, 2.2972265716789604, 2.2956070861547393, 2.302134415608195, 2.2979737200095363, 2.2953502816606575, 2.2909691874669047, 2.2974444722212235, 2.301594005500922, 2.300390833154014, 2.3014710176750515, 2.2938362329156208, 2.29842162991889, 2.300732043214114, 2.294023222954351, 2.2867637067002997, 2.2942263894050923, 2.2967010870437052, 2.2951148853282213, 2.2952705669636213, 2.2968103440712424, 2.297164567758325, 2.300218931587704, 2.2971703155747534, 2.3039734255807613, 2.300975881403843, 2.298166211022509, 2.2972687621393706, 2.29951678436213, 2.299839038459719, 2.292389526947031, 2.2947944610824766, 2.2965147972454263, 2.2967231862015556, 2.2970450294205773, 2.295755000628327, 2.294441515101325, 2.2949780248575173, 2.296844503943821, 2.300741754867711, 2.2999613557055945, 2.299686633162179, 2.2935450901458094, 2.302564524824001, 2.295633311991517, 2.2948997307111285, 2.297998282744385, 2.2949463278838382, 2.2896205478348244, 2.297528267780459, 2.299343552340146, 2.29293739857731, 2.2973366349239237, 2.2960816293245756, 2.292893432566328, 2.2996593952342166, 2.3002821178458364, 2.2897738479936622, 2.293882842998969, 2.2956764829508622, 2.290002407405411, 2.296869241808513, 2.2936484862531104, 2.299633385382838, 2.2910759175247124, 2.295153446227567, 2.2907053190601996, 2.2977885200632575, 2.297877502998122, 2.291066475270753, 2.298459343840664, 2.297368230909769, 2.295489342952952, 2.298977343740856, 2.288829051822368, 2.2941409632829926, 2.2951266680790106], 'acc': [0.109375, 0.0703125, 0.1015625, 0.125, 0.08984375, 0.09375, 0.125, 0.109375, 0.1171875, 0.1328125, 0.1484375, 0.109375, 0.09765625, 0.0703125, 0 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-b8c1e4b59d3a> in <module>
#       1 for ep in range(2):
#       2     mlp_stats.new_epoch()
# ----> 3     neural.train(mlp_model, sce, train_loader, optimizer, mlp_stats)
#       4     neural.validate(mlp_model, sce, valid_loader, mlp_stats)
#
# E:\Projects\py-berkley\neural\neural.py in train(model, crit, loader, optimizer, stats, subset_name)
#      37         _, pred = score.max(dim=1)
#      38         accuracy = torch.sum(pred == Y_batch).float() / X_batch.shape[0]
# ---> 39         stats.append_batch_stats(subset_name, loss=float(loss), acc=float(accuracy))
#      40         print_evaluation(loss, accuracy, step, subset_name)
#      41         step += 1
#
# E:\Projects\py-berkley\neural\Stats.py in append_batch_stats(self, subset, **stats)
#      18     def append_batch_stats(self, subset, **stats):
#      19         print("epochs", self._epochs)
# ---> 20         stop
#      21         if subset not in self._epochs[-1]:
#      22             self._epochs[-1][subset] = {}
#
# NameError: name 'stop' is not defined

# %%
mlp_stats.best_results()
# Out:
# Epoch 02      loss       acc
# train     2.292043  0.167588
# valid     2.288186  0.172776

# %%
mlp_stats.plot_by_epoch()

# %%
mlp_stats.plot_by_batch(block_len=10)

# %%
class LinearNet(nn.Module):
    def __init__(self, inputSize, outputSize):
        super().__init__()

        self.l1 = nn.Linear(inputSize, 1028)
        self.l2 = nn.Linear(1028, 512)
        self.l3 = nn.Linear(512, 512)
        self.l4 = nn.Linear(512, 128)
        self.l5 = nn.Linear(128, 128)
        self.l6 = nn.Linear(128, outputSize)

    def forward(self, x):
        x = self.l1(x)
        x = F.relu(x)

        x = self.l2(x)
        x = F.relu(x)

        x = self.l3(x)
        x = F.relu(x)

        x = self.l4(x)
        x = F.relu(x)

        x = self.l5(x)
        x = F.relu(x)

        x = self.l6(x)
        return x

# %%
# pokud vytvorime novou sit, vyresetujeme i statistiky
model = LinearNet(X_train.shape[1], torch.unique(y_train).shape[0])

stats = Stats()

# %%
device = 'cuda'
model.to(device)
model.cuda()
# Out:
# LinearNet(
#   (l1): Linear(in_features=3072, out_features=1028, bias=True)
#   (l2): Linear(in_features=1028, out_features=512, bias=True)
#   (l3): Linear(in_features=512, out_features=512, bias=True)
#   (l4): Linear(in_features=512, out_features=128, bias=True)
#   (l5): Linear(in_features=128, out_features=128, bias=True)
#   (l6): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# s novou siti musime obnovit i seznam parametru pro optimizer
# lepsich vysledku obvykle dosahuje SGD s momentum
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), )
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.9, verbose=True)
crit = nn.CrossEntropyLoss()
optimizer
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )

# %%
def train_step(model, loader, crit, optimizer, stats, subset_name='train'):
    model.train()
    step = 0
    for inputs, targets in loader.__iter__():
        # prepnout model do trenovaciho rezimu (tyka se vrstev jako Dropout nebo BatchNorm2d)


        # zajistit, aby model i data byla na stejnem zarizeni (cpu vs gpu)
        device = next(model.parameters()).device
        inputs, targets = inputs.to('cuda'), targets.to('cuda')

        # dopredny pruchod
        scores = model(inputs)

        # loss
        loss = crit(scores, targets)

        # pred zpetnym pruchodem vycistit prip. existujici gradienty z minulych iteraci
        optimizer.zero_grad()

        # zpetny pruchod, gradienty se ulozi primo do parametru modelu do atributu `grad`
        loss.backward()

        # update parametru na zaklade atributu `grad`
        optimizer.step()

        # vyhodnotime presnost
        _, pred = scores.max(dim=1)
        acc = torch.sum(pred == targets).float() / targets.shape[0]

        # update aktualnich statistik
        stats.append_batch_stats(subset_name, loss=float(loss), acc=float(acc))
        neural.print_evaluation(loss, acc, step, subset_name)

# %%
for ep in range(2):
    stats.new_epoch()
    train_step(model, train_loader, crit, optimizer, stats)
    neural.validate(model, crit, valid_loader, stats)
# Out:
# train data stats for 0 step
# Loss = 2.299
# Accuracy = 0.105
# ------------------------------
# train data stats for 0 step
# Loss = 2.307
# Accuracy = 0.098
# ------------------------------
# train data stats for 0 step
# Loss = 2.300
# Accuracy = 0.098
# ------------------------------
# train data stats for 0 step
# Loss = 2.300
# Accuracy = 0.094
# ------------------------------
# train data stats for 0 step
# Loss = 2.292
# Accuracy = 0.133
# ------------------------------
# train data stats for 0 step
# Loss = 2.298
# Accuracy = 0.125
# ------------------------------
# train data stats for 0 step
# Loss = 2.272
# Accuracy = 0.121
# ------------------------------
# train data stats for 0 step
# Loss = 2.266
# Accuracy = 0.156
# ------------------------------
# train data stats for 0 step
# Loss = 2.241
# Accuracy = 0.184
# ------------------------------
# train data stats for 0 step
# Loss = 2.183
# Accuracy = 0.184
# ------------------------------
# train data stats for 0 step
# Loss = 2.311
# Accuracy = 0.109
# ------------------------------
# train data stats for 0 step
# Loss = 2.143
# Accuracy = 0.191
# ------------------------------
# train data stats for 0 step
# Loss = 2.221
# Accuracy = 0.145
# ------------------------------
# train data stats for 0 step
# Loss = 2.144
# Accuracy = 0.164
# ------------------------------
# train data stats for 0 step
# Loss = 2.184
# Accuracy = 0.145
# ------------------------------
# train data stats for 0 step
# Loss = 2.160
# Accuracy = 0.137
# ------------------------------
# train data stats for 0 step
# Loss = 2.229
# Accuracy = 0.164
# ------------------------------
# train data stats for 0 step
# Loss = 2.161
# Accuracy = 0.137
# ------------------------------
# train data stats for 0 step
# Loss = 2.109
# Accuracy = 0.160
# ------------------------------
# train data stats for 0 step
# Loss = 2.259
# Accuracy = 0.133
# ------------------------------
# train data stats for 0 step
# Loss = 2.125
# Accuracy = 0.156
# ------------------------------
# train data stats for 0 step
# Loss = 2.151
# Accuracy = 0.188
# ------------------------------
# train data stats for 0 step
# Loss = 2.157
# Accuracy = 0.145
# ------------------------------
# train data stats for 0 step
# Loss = 2.131
# Accuracy = 0.168
# ------------------------------
# train data stats for 0 step
# Loss = 2.128
# Accuracy = 0.172
# ------------------------------
# train data stats for 0 step
# Loss = 2.132
# Accuracy = 0.156
# ------------------------------
# train data stats for 0 step
# Loss = 2.061
# Accuracy = 0.199
# ------------------------------
# train data stats for 0 step
# Loss = 2.100
# Accuracy = 0.207
# ------------------------------
# train data stats for 0 step
# Loss = 2.156
# Accuracy = 0.152
# ------------------------------
# train data stats for 0 step
# Loss = 2.080
# Accuracy = 0.180
# ------------------------------
# train data stats for 0 step
# Loss = 2.153
# Accuracy = 0.164
# ------------------------------
# train data stats for 0 step
# Loss = 2.053
# Accuracy = 0.160
# ------------------------------
# train data stats for 0 step
# Loss = 2.087
# Accuracy = 0.191
# ------------------------------
# train data stats for 0 step
# Loss = 2.131
# Accuracy = 0.180
# ------------------------------
# train data stats for 0 step
# Loss = 1.989
# Accuracy = 0.215
# ------------------------------
# train data stats for 0 step
# Loss = 2.066
# Accuracy = 0.195
# ------------------------------
# train data stats for 0 step
# Loss = 2.032
# Accuracy = 0.172
# ------------------------------
# train data stats for 0 step
# Loss = 2.101
# Accuracy = 0.137
# ------------------------------
# train data stats for 0 step
# Loss = 2.104
# Accuracy = 0.152
# ------------------------------
# train data stats for 0 step
# Loss = 2.164
# Accuracy = 0.180
# ------------------------------
# train data stats for 0 step
# Loss = 2.070
# Accuracy = 0.191
# ------------------------------
# train data stats for 0 step
# Loss = 2.081
# Accuracy = 0.207
# ------------------------------
# train data stats for 0 step
# Loss = 2.016
# Accuracy = 0.223
# ------------------------------
# train data stats for 0 step
# Loss = 2.116
# Accuracy = 0.172
# ------------------------------
# train data stats for 0 step
# Loss = 2.046
# Accuracy = 0.191
# ------------------------------
# train data stats for 0 step
# Loss = 2.098
# Accuracy = 0.195
# ------------------------------
# train data stats for 0 step
# Loss = 2.114
# Accuracy = 0.199
# ------------------------------
# train data stats for 0 step
# Loss = 2.064
# Accuracy = 0.195
# ------------------------------
# train data stats for 0 step
# Loss = 2.083
# Accuracy = 0.203
# ------------------------------
# train data stats for 0 step
# Loss = 2.051
# Accuracy = 0.188
# ------------------------------
# train data stats for 0 step
# Loss = 2.055
# Accuracy = 0.203
# ------------------------------
# train data stats for 0 step
# Loss = 2.067
# Accuracy = 0.180
# ------------------------------
# train data stats for 0 step
# Loss = 2.072
# Accuracy = 0.160
# ------------------------------
# train data stats for 0 step
# Loss = 2.108
# Accuracy = 0.180
# ------------------------------
# train data stats for 0 step
# Loss = 2.061
# Accuracy = 0.199
# ------------------------------
# train data stats for 0 step
# Loss = 2.085
# Accuracy = 0.230
# ------------------------------
# train data stats for 0 step
# Loss = 2.083
# Accuracy = 0.223
# ------------------------------
# train data stats for 0 step
# Loss = 2.031
# Accuracy = 0.215
# ------------------------------
# train data stats for 0 step
# Loss = 2.053
# Accuracy = 0.227
# ------------------------------
# train data stats for 0 step
# Loss = 2.030
# Accuracy = 0.230
# ------------------------------
# train data stats for 0 step
# Loss = 2.029
# Accuracy = 0.191
# ------------------------------
# train data stats for 0 step
# Loss = 2.056
# Accuracy = 0.203
# ------------------------------
# train data stats for 0 step
# Loss = 2.002
# Accuracy = 0.188
# ------------------------------
# train data stats for 0 step
# Loss = 2.040
# Accuracy = 0.234
# ------------------------------
# train data stats for 0 step
# Loss = 1.999
# Accuracy = 0.246
# ------------------------------
# train data stats for 0 step
# Loss = 2.016
# Accuracy = 0.227
# ------------------------------
# train data stats for 0 step
# Loss = 1.995
# Accuracy = 0.262
# ------------------------------
# train data stats for 0 step
# Loss = 1.990
# Accuracy = 0.234
# ------------------------------
# train data stats for 0 step
# Loss = 2.033
# Accuracy = 0.250
# ------------------------------
# train data stats for 0 step
# Loss = 1.965
# Accuracy = 0.281
# ------------------------------
# train data stats for 0 step
# Loss = 2.043
# Accuracy = 0.219
# ------------------------------
# train data stats for 0 step
# Loss = 1.934
# Accuracy = 0.277
# ------------------------------
# train data stats for 0 step
# Loss = 1.963
# Accuracy = 0.277
# ------------------------------
# train data stats for 0 step
# Loss = 2.016
# Accuracy = 0.234
# ------------------------------
# train data stats for 0 step
# Loss = 2.051
# Accuracy = 0.223
# ------------------------------
# train data stats for 0 step
# Loss = 2.033
# Accuracy = 0.215
# ------------------------------
# train data stats for 0 step
# Loss = 1.933
# Accuracy = 0.262
# ------------------------------
# train data stats for 0 step
# Loss = 2.002
# Accuracy = 0.227
# ------------------------------
# train data stats for 0 step
# Loss = 2.013
# Accuracy = 0.242
# ------------------------------
# train data stats for 0 step
# Loss = 2.000
# Accuracy = 0.250
# ------------------------------
# train data stats for 0 step
# Loss = 1.983
# Accuracy = 0.266
# ------------------------------
# train data stats for 0 step
# Loss = 1.956
# Accuracy = 0.277
# ------------------------------
# train data stats for 0 step
# Loss = 2.011
# Accuracy = 0.219
# ------------------------------
# train data stats for 0 step
# Loss = 1.974
# Accuracy = 0.246
# ------------------------------
# train data stats for 0 step
# Loss = 2.045
# Accuracy = 0.262
# ------------------------------
# train data stats for 0 step
# Loss = 1.979
# Accuracy = 0.242
# ------------------------------
# train data stats for 0 step
# Loss = 1.953
# Accuracy = 0.238
# ------------------------------
# train data stats for 0 step
# Loss = 1.986
# Accuracy = 0.250
# ------------------------------
# train data stats for 0 step
# Loss = 1.973
# Accuracy = 0.285
# ------------------------------
# train data stats for 0 step
# Loss = 1.958
# Accuracy = 0.246
# ------------------------------
# train data stats for 0 step
# Loss = 1.940
# Accuracy = 0.254
# ------------------------------
# train data stats for 0 step
# Loss = 1.952
# Accuracy = 0.262
# ------------------------------
# train data stats for 0 step
# Loss = 1.967
# Accuracy = 0.246
# ------------------------------
# train data stats for 0 step
# Loss = 2.002
# Accuracy = 0.277
# ------------------------------
# train data stats for 0 step
# Loss = 1.926
# Accuracy = 0.297
# ------------------------------
# train data stats for 0 step
# Loss = 2.028
# Accuracy = 0.250
# ------------------------------
# train data stats for 0 step
# Loss = 1.977
# Accuracy = 0.293
# ------------------------------
# train data stats for 0 step
# Loss = 2.024
# Accuracy = 0.281
# ------------------------------
# train data stats for 0 step
# Loss = 1.946
# Accuracy = 0.230
# ------------------------------
# train data stats for 0 step
# Loss = 2.015
# Accuracy = 0.266
# ------------------------------
# train data stats for 0 step
# Loss = 2.020
# Accuracy = 0.250
# ------------------------------
# train data stats for 0 step
# Loss = 1.912
# Accuracy = 0.258
# ------------------------------
# train data stats for 0 step
# Loss = 1.989
# Accuracy = 0.289
# ------------------------------
# train data stats for 0 step
# Loss = 1.973
# Accuracy = 0.262
# ------------------------------
# train data stats for 0 step
# Loss = 2.035
# Accuracy = 0.234
# ------------------------------
# train data stats for 0 step
# Loss = 2.018
# Accuracy = 0.246
# ------------------------------
# train data stats for 0 step
# Loss = 1.969
# Accuracy = 0.270
# ------------------------------
# train data stats for 0 step
# Loss = 1.998
# Accuracy = 0.262
# ------------------------------
# train data stats for 0 step
# Loss = 1.980
# Accuracy = 0.273
# ------------------------------
# train data stats for 0 step
# Loss = 1.898
# Accuracy = 0.273
# ------------------------------
# train data stats for 0 step
# Loss = 1.907
# Accuracy = 0.293
# ------------------------------
# train data stats for 0 step
# Loss = 1.890
# Accuracy = 0.289
# ------------------------------
# train data stats for 0 step
# Loss = 1.976
# Accuracy = 0.258
# ------------------------------
# train data stats for 0 step
# Loss = 1.913
# Accuracy = 0.262
# ------------------------------
# train data stats for 0 step
# Loss = 1.814
# Accuracy = 0.332
# ------------------------------
# train data stats for 0 step
# Loss = 1.947
# Accuracy = 0.289
# ------------------------------
# train data stats for 0 step
# Loss = 1.950
# Accuracy = 0.250
# ------------------------------
# train data stats for 0 step
# Loss = 2.004
# Accuracy = 0.285
# ------------------------------
# train data stats for 0 step
# Loss = 1.959
# Accuracy = 0.270
# ------------------------------
# train data stats for 0 step
# Loss = 1.988
# Accuracy = 0.238
# ------------------------------
# train data stats for 0 step
# Loss = 1.921
# Accuracy = 0.289
# ------------------------------
# train data stats for 0 step
# Loss = 1.903
# Accuracy = 0.352
# ------------------------------
# train data stats for 0 step
# Loss = 2.039
# Accuracy = 0.246
# ------------------------------
# train data stats for 0 step
# Loss = 1.927
# Accuracy = 0.293
# ------------------------------
# train data stats for 0 step
# Loss = 1.875
# Accuracy = 0.328
# ------------------------------
# train data stats for 0 step
# Loss = 1.909
# Accuracy = 0.273
# ------------------------------
# train data stats for 0 step
# Loss = 1.854
# Accuracy = 0.297
# ------------------------------
# train data stats for 0 step
# Loss = 1.869
# Accuracy = 0.324
# ------------------------------
# train data stats for 0 step
# Loss = 1.839
# Accuracy = 0.316
# ------------------------------
# train data stats for 0 step
# Loss = 1.877
# Accuracy = 0.309
# ------------------------------
# train data stats for 0 step
# Loss = 1.894
# Accuracy = 0.301
# ------------------------------
# train data stats for 0 step
# Loss = 1.839
# Accuracy = 0.344
# ------------------------------
# train data stats for 0 step
# Loss = 1.829
# Accuracy = 0.328
# ------------------------------
# train data stats for 0 step
# Loss = 1.819
# Accuracy = 0.340
# ------------------------------
# train data stats for 0 step
# Loss = 1.861
# Accuracy = 0.328
# ------------------------------
# train data stats for 0 step
# Loss = 1.883
# Accuracy = 0.344
# ------------------------------
# train data stats for 0 step
# Loss = 1.815
# Accuracy = 0.355
# ------------------------------
# train data stats for 0 step
# Loss = 1.860
# Accuracy = 0.320
# ------------------------------
# train data stats for 0 step
# Loss = 1.991
# Accuracy = 0.246
# ------------------------------
# train data stats for 0 step
# Loss = 1.864
# Accuracy = 0.305
# ------------------------------
# train data stats for 0 step
# Loss = 1.801
# Accuracy = 0.328
# ------------------------------
# train data stats for 0 step
# Loss = 1.820
# Accuracy = 0.340
# ------------------------------
# train data stats for 0 step
# Loss = 1.866
# Accuracy = 0.324
# ------------------------------
# train data stats for 0 step
# Loss = 1.820
# Accuracy = 0.379
# ------------------------------
# train data stats for 0 step
# Loss = 1.883
# Accuracy = 0.285
# ------------------------------
# train data stats for 0 step
# Loss = 1.926
# Accuracy = 0.266
# ------------------------------
# train data stats for 0 step
# Loss = 1.840
# Accuracy = 0.332
# ------------------------------
# train data stats for 0 step
# Loss = 1.865
# Accuracy = 0.312
# ------------------------------
# train data stats for 0 step
# Loss = 1.872
# Accuracy = 0.328
# ------------------------------
# train data stats for 0 step
# Loss = 1.828
# Accuracy = 0.348
# ------------------------------
# train data stats for 0 step
# Loss = 1.841
# Accuracy = 0.301
# ------------------------------
# train data stats for 0 step
# Loss = 1.771
# Accuracy = 0.359
# ------------------------------
# train data stats for 0 step
# Loss = 1.825
# Accuracy = 0.324
# ------------------------------
# train data stats for 0 step
# Loss = 1.820
# Accuracy = 0.359
# ------------------------------
# train data stats for 0 step
# Loss = 1.811
# Accuracy = 0.324
# ------------------------------
# train data stats for 0 step
# Loss = 1.898
# Accuracy = 0.301
# ------------------------------
# train data stats for 0 step
# Loss = 1.919
# Accuracy = 0.324
# ------------------------------
# train data stats for 0 step
# Loss = 1.832
# Accuracy = 0.324
# ------------------------------
# train data stats for 0 step
# Loss = 1.964
# Accuracy = 0.277
# ------------------------------
# train data stats for 0 step
# Loss = 1.815
# Accuracy = 0.309
# ------------------------------
# train data stats for 0 step
# Loss = 1.896
# Accuracy = 0.305
# ------------------------------
# train data stats for 0 step
# Loss = 1.913
# Accuracy = 0.332
# ------------------------------
# train data stats for 0 step
# Loss = 1.943
# Accuracy = 0.281
# ------------------------------
# train data stats for 0 step
# Loss = 1.921
# Accuracy = 0.273
# ------------------------------
# train data stats for 0 step
# Loss = 1.843
# Accuracy = 0.355
# ------------------------------
# train data stats for 0 step
# Loss = 1.878
# Accuracy = 0.324
# ------------------------------
# train data stats for 0 step
# Loss = 1.884
# Accuracy = 0.297
# ------------------------------
# train data stats for 0 step
# Loss = 1.901
# Accuracy = 0.312
# ------------------------------
# train data stats for 0 step
# Loss = 1.897
# Accuracy = 0.277
# ------------------------------
# train data stats for 0 step
# Loss = 1.943
# Accuracy = 0.281
# ------------------------------
# train data stats for 0 step
# Loss = 1.871
# Accuracy = 0.281
# ------------------------------
# train data stats for 0 step
# Loss = 1.917
# Accuracy = 0.293
# ------------------------------
# train data stats for 0 step
# Loss = 1.818
# Accuracy = 0.320
# ------------------------------
# train data stats for 0 step
# Loss = 1.897
# Accuracy = 0.281
# ------------------------------
# train data stats for 0 step
# Loss = 1.806
# Accuracy = 0.324
# ------------------------------
# train data stats for 0 step
# Loss = 1.846
# Accuracy = 0.309
# ------------------------------
# train data stats for 0 step
# Loss = 1.897
# Accuracy = 0.262
# ------------------------------
# train data stats for 0 step
# Loss = 1.770
# Accuracy = 0.375
# ------------------------------
# train data stats for 0 step
# Loss = 1.762
# Accuracy = 0.363
# ------------------------------
# train data stats for 0 step
# Loss = 1.873
# Accuracy = 0.328
# ------------------------------
# train data stats for 0 step
# Loss = 1.917
# Accuracy = 0.285
# ------------------------------
# train data stats for 0 step
# Loss = 1.825
# Accuracy = 0.316
# ------------------------------
# train data stats for 0 step
# Loss = 1.804
# Accuracy = 0.379
# ------------------------------
# train data stats for 0 step
# Loss = 1.922
# Accuracy = 0.281
# ------------------------------
# train data stats for 0 step
# Loss = 1.823
# Accuracy = 0.316
# ------------------------------
# train data stats for 0 step
# Loss = 1.828
# Accuracy = 0.371
# ------------------------------
# train data stats for 0 step
# Loss = 1.813
# Accuracy = 0.344
# ------------------------------
# train data stats for 0 step
# Loss = 1.853
# Accuracy = 0.328
# ------------------------------
# train data stats for 0 step
# Loss = 1.927
# Accuracy = 0.285
# ------------------------------
# train data stats for 0 step
# Loss = 1.803
# Accuracy = 0.391
# ------------------------------
# train data stats for 0 step
# Loss = 1.942
# Accuracy = 0.309
# ------------------------------
# train data stats for 0 step
# Loss = 1.871
# Accuracy = 0.316
# ------------------------------
# train data stats for 0 step
# Loss = 1.824
# Accuracy = 0.324
# ------------------------------
# train data stats for 0 step
# Loss = 1.789
# Accuracy = 0.375
# ------------------------------
# train data stats for 0 step
# Loss = 1.831
# Accuracy = 0.363
# ------------------------------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-96-7c6da8cf756b> in <module>
#       2     stats.new_epoch()
#       3     train_step(model, train_loader, crit, optimizer, stats)
# ----> 4     neural.validate(model, crit, valid_loader, stats)
#
# E:\Projects\py-berkley\neural\neural.py in validate(model, crit, loader, stats, subset_name)
#      60
#      61         # forward
# ---> 62         score = model.forward(X_batch)
#      63
#      64         # loss
#
# <ipython-input-64-1b499c80af1b> in forward(self, x)
#      11
#      12     def forward(self, x):
# ---> 13         x = self.l1(x)
#      14         x = F.relu(x)
#      15
#
# E:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# E:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# E:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1688     if input.dim() == 2 and bias is not None:
#    1689         # fused op is marginally faster
# -> 1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
#    1692         output = input.matmul(weight.t())
#
# RuntimeError: Tensor for argument #2 'mat1' is on CPU, but expected it to be on GPU (while checking arguments for addmm)
